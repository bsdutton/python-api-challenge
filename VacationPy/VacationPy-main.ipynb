# %% [markdown]
# # VacationPy
# ----
#
# #### Create a heat map that displays the humidity for every city from WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from pprint import pprint
import country_converter as coco
from scipy import stats
import gmaps

# Import API key
from api_keys import weather_api_key
from config import gkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# configure Gmaps
gmaps.configure(api_key=gkey)
fig = gmaps.figure()

# Output File (CSV)
output_data_file = "fresh_vacation_output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Re-Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build the query for the for-loop
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
lat = []
long = []
temp = []
humid = []
clouds = []
winds = []
city1 = []
city2 = []
max_temp = []
country = []
datetime = []
print_request = []
print_response = []
print_dne = []

# %%
# Loops work on smaller range.  Reset and empty list by running codeblock where they created.
# Run loops and monitor print outputs.

# %%
for city in range(len(cities)):
    try:
        weather2 = requests.get(query_url + str(cities[city])).json()
        lat.append(weather2['coord']['lat'])
        long.append(weather2['coord']['lon'])
        temp.append(weather2['main']['feels_like'])
        max_temp.append(weather2['main']['temp_max'])
        humid.append(weather2['main']['humidity'])
        clouds.append(weather2['clouds']['all'])
        winds.append(weather2['wind']['speed'])
        city1.append(weather2['name'])
        country.append(weather2['sys']['country'])
        datetime.append(weather2['dt'])
        print(f"Request {city} sent for {cities[city]}.")
        print_request.append(f"Request {city} sent for {cities[city]}.")
        print(f"Response code {weather2['cod']} received for {cities[city]}.")
        print_response.append(f"Response code {weather2['cod']} received for {cities[city]}.")
    except:
        print(f"{cities[city]} does not exist in OpenWeatherMap.")
        city2.append(cities[city])
        print_dne.append(f"{cities[city]} does not exist in OpenWeatherMap.")
        pass
# Out:
# skalistyy does not exist in OpenWeatherMap.
# Request 1 sent for rikitea.
# Response code 200 received for rikitea.
# Request 2 sent for busselton.
# Response code 200 received for busselton.
# Request 3 sent for hithadhoo.
# Response code 200 received for hithadhoo.
# Request 4 sent for thompson.
# Response code 200 received for thompson.
# Request 5 sent for tasiilaq.
# Response code 200 received for tasiilaq.
# Request 6 sent for mataura.
# Response code 200 received for mataura.
# illoqqortoormiut does not exist in OpenWeatherMap.
# Request 8 sent for yellowknife.
# Response code 200 received for yellowknife.
# grand river south east does not exist in OpenWeatherMap.
# Request 10 sent for cabra.
# Response code 200 received for cabra.
# Request 11 sent for tiksi.
# Response code 200 received for tiksi.
# attawapiskat does not exist in OpenWeatherMap.
# Request 13 sent for kapaa.
# Response code 200 received for kapaa.
# Request 14 sent for kodiak.
# Response code 200 received for kodiak.
# Request 15 sent for mount isa.
# Response code 200 received for mount isa.
# Request 16 sent for port-gentil.
# Response code 200 received for port-gentil.
# Request 17 sent for emmett.
# Response code 200 received for emmett.
# nizhneyansk does not exist in OpenWeatherMap.
# Request 19 sent for grindavik.
# Response code 200 received for grindavik.
# Request 20 sent for porgera.
# Response code 200 received for porgera.
# Request 21 sent for tuatapere.
# Response code 200 received for tuatapere.
# Request 22 sent for tual.
# Response code 200 received for tual.
# Request 23 sent for garowe.
# Response code 200 received for garowe.
# Request 24 sent for bengkulu.
# Response code 200 received for bengkulu.
# Request 25 sent for ust-maya.
# Response code 200 received for ust-maya.
# Request 26 sent for awjilah.
# Response code 200 received for awjilah.
# Request 27 sent for tuensang.
# Response code 200 received for tuensang.
# Request 28 sent for bluff.
# Response code 200 received for bluff.
# taolanaro does not exist in OpenWeatherMap.
# Request 30 sent for moranbah.
# Response code 200 received for moranbah.
# Request 31 sent for butaritari.
# Response code 200 received for butaritari.
# Request 32 sent for atar.
# Response code 200 received for atar.
# Request 33 sent for karpathos.
# Response code 200 received for karpathos.
# Request 34 sent for saskylakh.
# Response code 200 received for saskylakh.
# Request 35 sent for hilo.
# Response code 200 received for hilo.
# Request 36 sent for severo-kurilsk.
# Response code 200 received for severo-kurilsk.
# Request 37 sent for vostok.
# Response code 200 received for vostok.
# Request 38 sent for ogbomosho.
# Response code 200 received for ogbomosho.
# Request 39 sent for tuktoyaktuk.
# Response code 200 received for tuktoyaktuk.
# Request 40 sent for punta arenas.
# Response code 200 received for punta arenas.
# Request 41 sent for harlingen.
# Response code 200 received for harlingen.
# Request 42 sent for arraial do cabo.
# Response code 200 received for arraial do cabo.
# Request 43 sent for port elizabeth.
# Response code 200 received for port elizabeth.
# Request 44 sent for colac.
# Response code 200 received for colac.
# Request 45 sent for damietta.
# Response code 200 received for damietta.
# Request 46 sent for bathsheba.
# Response code 200 received for bathsheba.
# Request 47 sent for bethel.
# Response code 200 received for bethel.
# Request 48 sent for abay.
# Response code 200 received for abay.
# Request 49 sent for jamestown.
# Response code 200 received for jamestown.
# Request 50 sent for lata.
# Response code 200 received for lata.
# Request 51 sent for saint-philippe.
# Response code 200 received for saint-philippe.
# Request 52 sent for qaanaaq.
# Response code 200 received for qaanaaq.
# Request 53 sent for homer.
# Response code 200 received for homer.
# Request 54 sent for georgetown.
# Response code 200 received for georgetown.
# Request 55 sent for qaqortoq.
# Response code 200 received for qaqortoq.
# Request 56 sent for laela.
# Response code 200 received for laela.
# Request 57 sent for port alfred.
# Response code 200 received for port alfred.
# Request 58 sent for ayagoz.
# Response code 200 received for ayagoz.
# Request 59 sent for lebu.
# Response code 200 received for lebu.
# Request 60 sent for sao filipe.
# Response code 200 received for sao filipe.
# Request 61 sent for along.
# Response code 200 received for along.
# Request 62 sent for barrow.
# Response code 200 received for barrow.
# vaitupu does not exist in OpenWeatherMap.
# Request 64 sent for cabo san lucas.
# Response code 200 received for cabo san lucas.
# amderma does not exist in OpenWeatherMap.
# Request 66 sent for san patricio.
# Response code 200 received for san patricio.
# Request 67 sent for ushuaia.
# Response code 200 received for ushuaia.
# sentyabrskiy does not exist in OpenWeatherMap.
# Request 69 sent for wagar.
# Response code 200 received for wagar.
# Request 70 sent for felipe carrillo puerto.
# Response code 200 received for felipe carrillo puerto.
# Request 71 sent for mincivan.
# Response code 200 received for mincivan.
# Request 72 sent for westport.
# Response code 200 received for westport.
# Request 73 sent for chokurdakh.
# Response code 200 received for chokurdakh.
# Request 74 sent for elko.
# Response code 200 received for elko.
# Request 75 sent for hofn.
# Response code 200 received for hofn.
# Request 76 sent for san jeronimo.
# Response code 200 received for san jeronimo.
# Request 77 sent for cherskiy.
# Response code 200 received for cherskiy.
# Request 78 sent for avarua.
# Response code 200 received for avarua.
# Request 79 sent for namie.
# Response code 200 received for namie.
# Request 80 sent for castro.
# Response code 200 received for castro.
# Request 81 sent for luderitz.
# Response code 200 received for luderitz.
# Request 82 sent for cape town.
# Response code 200 received for cape town.
# nguiu does not exist in OpenWeatherMap.
# Request 84 sent for roald.
# Response code 200 received for roald.
# Request 85 sent for abu kamal.
# Response code 200 received for abu kamal.
# Request 86 sent for terrace bay.
# Response code 200 received for terrace bay.
# Request 87 sent for hobart.
# Response code 200 received for hobart.
# Request 88 sent for bialogard.
# Response code 200 received for bialogard.
# Request 89 sent for sola.
# Response code 200 received for sola.
# Request 90 sent for wanlaweyn.
# Response code 200 received for wanlaweyn.
# Request 91 sent for albany.
# Response code 200 received for albany.
# Request 92 sent for vanavara.
# Response code 200 received for vanavara.
# Request 93 sent for nabire.
# Response code 200 received for nabire.
# Request 94 sent for sambava.
# Response code 200 received for sambava.
# Request 95 sent for vaini.
# Response code 200 received for vaini.
# warqla does not exist in OpenWeatherMap.
# Request 97 sent for puerto ayora.
# Response code 200 received for puerto ayora.
# Request 98 sent for hasaki.
# Response code 200 received for hasaki.
# Request 99 sent for la asuncion.
# Response code 200 received for la asuncion.
# Request 100 sent for wanning.
# Response code 200 received for wanning.
# Request 101 sent for nikolskoye.
# Response code 200 received for nikolskoye.
# Request 102 sent for khatanga.
# Response code 200 received for khatanga.
# Request 103 sent for general higinio morinigo.
# Response code 200 received for general higinio morinigo.
# Request 104 sent for mar del plata.
# Response code 200 received for mar del plata.
# Request 105 sent for provideniya.
# Response code 200 received for provideniya.
# Request 106 sent for kajiado.
# Response code 200 received for kajiado.
# Request 107 sent for whitehorse.
# Response code 200 received for whitehorse.
# Request 108 sent for san-pedro.
# Response code 200 received for san-pedro.
# Request 109 sent for half moon bay.
# Response code 200 received for half moon bay.
# Request 110 sent for quepos.
# Response code 200 received for quepos.
# Request 111 sent for san juan.
# Response code 200 received for san juan.
# Request 112 sent for aksarka.
# Response code 200 received for aksarka.
# Request 113 sent for bom jardim.
# Response code 200 received for bom jardim.
# Request 114 sent for wakkanai.
# Response code 200 received for wakkanai.
# Request 115 sent for dikson.
# Response code 200 received for dikson.
# Request 116 sent for upernavik.
# Response code 200 received for upernavik.
# Request 117 sent for buluang.
# Response code 200 received for buluang.
# Request 118 sent for new norfolk.
# Response code 200 received for new norfolk.
# Request 119 sent for alofi.
# Response code 200 received for alofi.
# Request 120 sent for vilyuysk.
# Response code 200 received for vilyuysk.
# Request 121 sent for piranhas.
# Response code 200 received for piranhas.
# Request 122 sent for yagodnoye.
# Response code 200 received for yagodnoye.
# Request 123 sent for baykit.
# Response code 200 received for baykit.
# Request 124 sent for kruisfontein.
# Response code 200 received for kruisfontein.
# Request 125 sent for camana.
# Response code 200 received for camana.
# Request 126 sent for pangody.
# Response code 200 received for pangody.
# Request 127 sent for lebedinyy.
# Response code 200 received for lebedinyy.
# Request 128 sent for bugulma.
# Response code 200 received for bugulma.
# Request 129 sent for bredasdorp.
# Response code 200 received for bredasdorp.
# Request 130 sent for ranipur.
# Response code 200 received for ranipur.
# Request 131 sent for saldanha.
# Response code 200 received for saldanha.
# Request 132 sent for brae.
# Response code 200 received for brae.
# mallama does not exist in OpenWeatherMap.
# Request 134 sent for rio gallegos.
# Response code 200 received for rio gallegos.
# Request 135 sent for sao gabriel da cachoeira.
# Response code 200 received for sao gabriel da cachoeira.
# Request 136 sent for port shepstone.
# Response code 200 received for port shepstone.
# Request 137 sent for kailua.
# Response code 200 received for kailua.
# Request 138 sent for mahenge.
# Response code 200 received for mahenge.
# Request 139 sent for mahebourg.
# Response code 200 received for mahebourg.
# Request 140 sent for fort nelson.
# Response code 200 received for fort nelson.
# Request 141 sent for yuncheng.
# Response code 200 received for yuncheng.
# Request 142 sent for rabo de peixe.
# Response code 200 received for rabo de peixe.
# Request 143 sent for houma.
# Response code 200 received for houma.
# Request 144 sent for ponta do sol.
# Response code 200 received for ponta do sol.
# Request 145 sent for riyadh.
# Response code 200 received for riyadh.
# Request 146 sent for dingle.
# Response code 200 received for dingle.
# Request 147 sent for caconda.
# Response code 200 received for caconda.
# Request 148 sent for puerto ayacucho.
# Response code 200 received for puerto ayacucho.
# Request 149 sent for touros.
# Response code 200 received for touros.
# Request 150 sent for saint-francois.
# Response code 200 received for saint-francois.
# Request 151 sent for pevek.
# Response code 200 received for pevek.
# Request 152 sent for charyshskoye.
# Response code 200 received for charyshskoye.
# Request 153 sent for vila franca do campo.
# Response code 200 received for vila franca do campo.
# Request 154 sent for qingdao.
# Response code 200 received for qingdao.
# Request 155 sent for port moresby.
# Response code 200 received for port moresby.
# Request 156 sent for atuona.
# Response code 200 received for atuona.
# Request 157 sent for honningsvag.
# Response code 200 received for honningsvag.
# Request 158 sent for flinders.
# Response code 200 received for flinders.
# Request 159 sent for ancud.
# Response code 200 received for ancud.
# Request 160 sent for chuy.
# Response code 200 received for chuy.
# Request 161 sent for omboue.
# Response code 200 received for omboue.
# Request 162 sent for dunedin.
# Response code 200 received for dunedin.
# Request 163 sent for hovd.
# Response code 200 received for hovd.
# Request 164 sent for faanui.
# Response code 200 received for faanui.
# Request 165 sent for sitka.
# Response code 200 received for sitka.
# Request 166 sent for cavalcante.
# Response code 200 received for cavalcante.
# Request 167 sent for ribeira grande.
# Response code 200 received for ribeira grande.
# Request 168 sent for road town.
# Response code 200 received for road town.
# Request 169 sent for tongliao.
# Response code 200 received for tongliao.
# Request 170 sent for kavieng.
# Response code 200 received for kavieng.
# Request 171 sent for beringovskiy.
# Response code 200 received for beringovskiy.
# Request 172 sent for ayan.
# Response code 200 received for ayan.
# Request 173 sent for moussoro.
# Response code 200 received for moussoro.
# Request 174 sent for torbay.
# Response code 200 received for torbay.
# Request 175 sent for victoria.
# Response code 200 received for victoria.
# Request 176 sent for eirunepe.
# Response code 200 received for eirunepe.
# Request 177 sent for archidona.
# Response code 200 received for archidona.
# Request 178 sent for katsuura.
# Response code 200 received for katsuura.
# Request 179 sent for taltal.
# Response code 200 received for taltal.
# Request 180 sent for carnarvon.
# Response code 200 received for carnarvon.
# Request 181 sent for kirksville.
# Response code 200 received for kirksville.
# Request 182 sent for diffa.
# Response code 200 received for diffa.
# Request 183 sent for esperance.
# Response code 200 received for esperance.
# Request 184 sent for luoyang.
# Response code 200 received for luoyang.
# Request 185 sent for ahuimanu.
# Response code 200 received for ahuimanu.
# Request 186 sent for kuching.
# Response code 200 received for kuching.
# Request 187 sent for muswellbrook.
# Response code 200 received for muswellbrook.
# Request 188 sent for rocha.
# Response code 200 received for rocha.
# Request 189 sent for kropotkin.
# Response code 200 received for kropotkin.
# Request 190 sent for novokayakent.
# Response code 200 received for novokayakent.
# Request 191 sent for souillac.
# Response code 200 received for souillac.
# marcona does not exist in OpenWeatherMap.
# Request 193 sent for kaitangata.
# Response code 200 received for kaitangata.
# Request 194 sent for coahuayana.
# Response code 200 received for coahuayana.
# barentsburg does not exist in OpenWeatherMap.
# Request 196 sent for kawalu.
# Response code 200 received for kawalu.
# Request 197 sent for pacific grove.
# Response code 200 received for pacific grove.
# Request 198 sent for nanakuli.
# Response code 200 received for nanakuli.
# Request 199 sent for shabo.
# Response code 200 received for shabo.
# Request 200 sent for chaiya.
# Response code 200 received for chaiya.
# Request 201 sent for andenes.
# Response code 200 received for andenes.
# Request 202 sent for jurm.
# Response code 200 received for jurm.
# Request 203 sent for tabuk.
# Response code 200 received for tabuk.
# Request 204 sent for qeshm.
# Response code 200 received for qeshm.
# Request 205 sent for angoche.
# Response code 200 received for angoche.
# Request 206 sent for makakilo city.
# Response code 200 received for makakilo city.
# Request 207 sent for lorengau.
# Response code 200 received for lorengau.
# Request 208 sent for golden.
# Response code 200 received for golden.
# Request 209 sent for te anau.
# Response code 200 received for te anau.
# sorvag does not exist in OpenWeatherMap.
# Request 211 sent for russell.
# Response code 200 received for russell.
# belushya guba does not exist in OpenWeatherMap.
# Request 213 sent for bose.
# Response code 200 received for bose.
# Request 214 sent for ahipara.
# Response code 200 received for ahipara.
# Request 215 sent for emerald.
# Response code 200 received for emerald.
# toliary does not exist in OpenWeatherMap.
# Request 217 sent for bintulu.
# Response code 200 received for bintulu.
# Request 218 sent for east london.
# Response code 200 received for east london.
# palabuhanratu does not exist in OpenWeatherMap.
# Request 220 sent for aklavik.
# Response code 200 received for aklavik.
# Request 221 sent for kavaratti.
# Response code 200 received for kavaratti.
# Request 222 sent for hay river.
# Response code 200 received for hay river.
# Request 223 sent for den helder.
# Response code 200 received for den helder.
# Request 224 sent for barrhead.
# Response code 200 received for barrhead.
# viligili does not exist in OpenWeatherMap.
# Request 226 sent for inuvik.
# Response code 200 received for inuvik.
# Request 227 sent for yako.
# Response code 200 received for yako.
# Request 228 sent for ilulissat.
# Response code 200 received for ilulissat.
# Request 229 sent for irsha.
# Response code 200 received for irsha.
# Request 230 sent for huarmey.
# Response code 200 received for huarmey.
# Request 231 sent for tiarei.
# Response code 200 received for tiarei.
# Request 232 sent for huacho.
# Response code 200 received for huacho.
# Request 233 sent for korla.
# Response code 200 received for korla.
# Request 234 sent for clyde river.
# Response code 200 received for clyde river.
# Request 235 sent for haines junction.
# Response code 200 received for haines junction.
# Request 236 sent for cidreira.
# Response code 200 received for cidreira.
# Request 237 sent for pandan.
# Response code 200 received for pandan.
# samusu does not exist in OpenWeatherMap.
# Request 239 sent for datong.
# Response code 200 received for datong.
# Request 240 sent for nagbalaye.
# Response code 200 received for nagbalaye.
# Request 241 sent for kulob.
# Response code 200 received for kulob.
# Request 242 sent for verkhnyaya inta.
# Response code 200 received for verkhnyaya inta.
# Request 243 sent for hamilton.
# Response code 200 received for hamilton.
# Request 244 sent for kudahuvadhoo.
# Response code 200 received for kudahuvadhoo.
# mys shmidta does not exist in OpenWeatherMap.
# barbar does not exist in OpenWeatherMap.
# Request 247 sent for hobyo.
# Response code 200 received for hobyo.
# rawannawi does not exist in OpenWeatherMap.
# Request 249 sent for nago.
# Response code 200 received for nago.
# Request 250 sent for lompoc.
# Response code 200 received for lompoc.
# Request 251 sent for chenzhou.
# Response code 200 received for chenzhou.
# Request 252 sent for palmas.
# Response code 200 received for palmas.
# Request 253 sent for hambantota.
# Response code 200 received for hambantota.
# Request 254 sent for muzaffargarh.
# Response code 200 received for muzaffargarh.
# Request 255 sent for tazovskiy.
# Response code 200 received for tazovskiy.
# Request 256 sent for poya.
# Response code 200 received for poya.
# Request 257 sent for nanortalik.
# Response code 200 received for nanortalik.
# Request 258 sent for haysyn.
# Response code 200 received for haysyn.
# Request 259 sent for beipiao.
# Response code 200 received for beipiao.
# Request 260 sent for orlik.
# Response code 200 received for orlik.
# Request 261 sent for southbridge.
# Response code 200 received for southbridge.
# Request 262 sent for port hedland.
# Response code 200 received for port hedland.
# kamenskoye does not exist in OpenWeatherMap.
# Request 264 sent for batemans bay.
# Response code 200 received for batemans bay.
# Request 265 sent for benguela.
# Response code 200 received for benguela.
# Request 266 sent for kushmurun.
# Response code 200 received for kushmurun.
# Request 267 sent for dicabisagan.
# Response code 200 received for dicabisagan.
# Request 268 sent for kahului.
# Response code 200 received for kahului.
# Request 269 sent for bahar.
# Response code 200 received for bahar.
# Request 270 sent for rosetown.
# Response code 200 received for rosetown.
# Request 271 sent for skibotn.
# Response code 200 received for skibotn.
# Request 272 sent for coquimbo.
# Response code 200 received for coquimbo.
# Request 273 sent for isangel.
# Response code 200 received for isangel.
# Request 274 sent for borodino.
# Response code 200 received for borodino.
# Request 275 sent for bandarbeyla.
# Response code 200 received for bandarbeyla.
# khonuu does not exist in OpenWeatherMap.
# Request 277 sent for khasan.
# Response code 200 received for khasan.
# Request 278 sent for puerto narino.
# Response code 200 received for puerto narino.
# Request 279 sent for saint-pierre.
# Response code 200 received for saint-pierre.
# Request 280 sent for vardo.
# Response code 200 received for vardo.
# Request 281 sent for moshny.
# Response code 200 received for moshny.
# Request 282 sent for lamesa.
# Response code 200 received for lamesa.
# Request 283 sent for semporna.
# Response code 200 received for semporna.
# Request 284 sent for matagami.
# Response code 200 received for matagami.
# Request 285 sent for panacan.
# Response code 200 received for panacan.
# Request 286 sent for pihuamo.
# Response code 200 received for pihuamo.
# Request 287 sent for sohag.
# Response code 200 received for sohag.
# Request 288 sent for talnakh.
# Response code 200 received for talnakh.
# Request 289 sent for la rioja.
# Response code 200 received for la rioja.
# Request 290 sent for bodden town.
# Response code 200 received for bodden town.
# Request 291 sent for abashiri.
# Response code 200 received for abashiri.
# Request 292 sent for fare.
# Response code 200 received for fare.
# Request 293 sent for karlshamn.
# Response code 200 received for karlshamn.
# tsihombe does not exist in OpenWeatherMap.
# Request 295 sent for yerbogachen.
# Response code 200 received for yerbogachen.
# Request 296 sent for nome.
# Response code 200 received for nome.
# Request 297 sent for tezu.
# Response code 200 received for tezu.
# gafurov does not exist in OpenWeatherMap.
# Request 299 sent for raton.
# Response code 200 received for raton.
# Request 300 sent for college.
# Response code 200 received for college.
# Request 301 sent for airai.
# Response code 200 received for airai.
# Request 302 sent for fairview.
# Response code 200 received for fairview.
# Request 303 sent for hermanus.
# Response code 200 received for hermanus.
# Request 304 sent for cascais.
# Response code 200 received for cascais.
# Request 305 sent for baker city.
# Response code 200 received for baker city.
# Request 306 sent for bosaso.
# Response code 200 received for bosaso.
# Request 307 sent for geraldton.
# Response code 200 received for geraldton.
# Request 308 sent for hualmay.
# Response code 200 received for hualmay.
# Request 309 sent for yar.
# Response code 200 received for yar.
# Request 310 sent for paamiut.
# Response code 200 received for paamiut.
# Request 311 sent for manokwari.
# Response code 200 received for manokwari.
# Request 312 sent for iqaluit.
# Response code 200 received for iqaluit.
# Request 313 sent for sterling.
# Response code 200 received for sterling.
# Request 314 sent for ede.
# Response code 200 received for ede.
# Request 315 sent for ignacio zaragoza.
# Response code 200 received for ignacio zaragoza.
# Request 316 sent for henties bay.
# Response code 200 received for henties bay.
# Request 317 sent for egvekinot.
# Response code 200 received for egvekinot.
# Request 318 sent for itarema.
# Response code 200 received for itarema.
# Request 319 sent for tynda.
# Response code 200 received for tynda.
# Request 320 sent for nizhniy kuranakh.
# Response code 200 received for nizhniy kuranakh.
# Request 321 sent for pisco.
# Response code 200 received for pisco.
# tumannyy does not exist in OpenWeatherMap.
# Request 323 sent for granada.
# Response code 200 received for granada.
# Request 324 sent for jining.
# Response code 200 received for jining.
# Request 325 sent for kandiari.
# Response code 200 received for kandiari.
# Request 326 sent for jalu.
# Response code 200 received for jalu.
# Request 327 sent for mandurah.
# Response code 200 received for mandurah.
# Request 328 sent for kenai.
# Response code 200 received for kenai.
# Request 329 sent for killam.
# Response code 200 received for killam.
# Request 330 sent for bayonet point.
# Response code 200 received for bayonet point.
# Request 331 sent for umm lajj.
# Response code 200 received for umm lajj.
# Request 332 sent for iskateley.
# Response code 200 received for iskateley.
# Request 333 sent for asyut.
# Response code 200 received for asyut.
# Request 334 sent for goderich.
# Response code 200 received for goderich.
# Request 335 sent for ulaangom.
# Response code 200 received for ulaangom.
# Request 336 sent for vavoua.
# Response code 200 received for vavoua.
# Request 337 sent for sinnamary.
# Response code 200 received for sinnamary.
# Request 338 sent for gliwice.
# Response code 200 received for gliwice.
# Request 339 sent for port lincoln.
# Response code 200 received for port lincoln.
# Request 340 sent for pahrump.
# Response code 200 received for pahrump.
# bac can does not exist in OpenWeatherMap.
# saleaula does not exist in OpenWeatherMap.
# Request 343 sent for oktyabrskoye.
# Response code 200 received for oktyabrskoye.
# Request 344 sent for pangnirtung.
# Response code 200 received for pangnirtung.
# Request 345 sent for pringsewu.
# Response code 200 received for pringsewu.
# Request 346 sent for montes claros.
# Response code 200 received for montes claros.
# Request 347 sent for ostrovnoy.
# Response code 200 received for ostrovnoy.
# Request 348 sent for nanga eboko.
# Response code 200 received for nanga eboko.
# Request 349 sent for la ronge.
# Response code 200 received for la ronge.
# Request 350 sent for milkovo.
# Response code 200 received for milkovo.
# Request 351 sent for grand-santi.
# Response code 200 received for grand-santi.
# Request 352 sent for olinda.
# Response code 200 received for olinda.
# Request 353 sent for bograd.
# Response code 200 received for bograd.
# mullaitivu does not exist in OpenWeatherMap.
# Request 355 sent for vung tau.
# Response code 200 received for vung tau.
# Request 356 sent for acapulco.
# Response code 200 received for acapulco.
# Request 357 sent for olutanga.
# Response code 200 received for olutanga.
# Request 358 sent for lomita.
# Response code 200 received for lomita.
# Request 359 sent for labuhan.
# Response code 200 received for labuhan.
# Request 360 sent for kamaishi.
# Response code 200 received for kamaishi.
# Request 361 sent for bambous virieux.
# Response code 200 received for bambous virieux.
# caiuti does not exist in OpenWeatherMap.
# Request 363 sent for noicattaro.
# Response code 200 received for noicattaro.
# Request 364 sent for asau.
# Response code 200 received for asau.
# Request 365 sent for praia da vitoria.
# Response code 200 received for praia da vitoria.
# Request 366 sent for noda.
# Response code 200 received for noda.
# Request 367 sent for petropavlovsk-kamchatskiy.
# Response code 200 received for petropavlovsk-kamchatskiy.
# Request 368 sent for tarrega.
# Response code 200 received for tarrega.
# Request 369 sent for vangaindrano.
# Response code 200 received for vangaindrano.
# Request 370 sent for mehamn.
# Response code 200 received for mehamn.
# Request 371 sent for longyearbyen.
# Response code 200 received for longyearbyen.
# Request 372 sent for obo.
# Response code 200 received for obo.
# Request 373 sent for buraydah.
# Response code 200 received for buraydah.
# Request 374 sent for maarianhamina.
# Response code 200 received for maarianhamina.
# Request 375 sent for carbonear.
# Response code 200 received for carbonear.
# Request 376 sent for komsomolskiy.
# Response code 200 received for komsomolskiy.
# Request 377 sent for xuddur.
# Response code 200 received for xuddur.
# Request 378 sent for matai.
# Response code 200 received for matai.
# Request 379 sent for loudeac.
# Response code 200 received for loudeac.
# Request 380 sent for kualakapuas.
# Response code 200 received for kualakapuas.
# Request 381 sent for cayenne.
# Response code 200 received for cayenne.
# Request 382 sent for tanete.
# Response code 200 received for tanete.
# Request 383 sent for marfino.
# Response code 200 received for marfino.
# Request 384 sent for raub.
# Response code 200 received for raub.
# Request 385 sent for floriano.
# Response code 200 received for floriano.
# Request 386 sent for norman wells.
# Response code 200 received for norman wells.
# tabulbah does not exist in OpenWeatherMap.
# Request 388 sent for port hardy.
# Response code 200 received for port hardy.
# Request 389 sent for jingdezhen.
# Response code 200 received for jingdezhen.
# louisbourg does not exist in OpenWeatherMap.
# haibowan does not exist in OpenWeatherMap.
# Request 392 sent for ternate.
# Response code 200 received for ternate.
# Request 393 sent for llanes.
# Response code 200 received for llanes.
# Request 394 sent for severo-yeniseyskiy.
# Response code 200 received for severo-yeniseyskiy.
# Request 395 sent for arman.
# Response code 200 received for arman.
# Request 396 sent for kathmandu.
# Response code 200 received for kathmandu.
# Request 397 sent for muros.
# Response code 200 received for muros.
# barawe does not exist in OpenWeatherMap.
# Request 399 sent for enschede.
# Response code 200 received for enschede.
# Request 400 sent for jalapa.
# Response code 200 received for jalapa.
# Request 401 sent for cookeville.
# Response code 200 received for cookeville.
# Request 402 sent for poyarkovo.
# Response code 200 received for poyarkovo.
# Request 403 sent for berlevag.
# Response code 200 received for berlevag.
# Request 404 sent for katherine.
# Response code 200 received for katherine.
# Request 405 sent for sompeta.
# Response code 200 received for sompeta.
# Request 406 sent for grand baie.
# Response code 200 received for grand baie.
# Request 407 sent for port augusta.
# Response code 200 received for port augusta.
# Request 408 sent for villa maria.
# Response code 200 received for villa maria.
# Request 409 sent for maceio.
# Response code 200 received for maceio.
# Request 410 sent for christchurch.
# Response code 200 received for christchurch.
# Request 411 sent for fortuna.
# Response code 200 received for fortuna.
# Request 412 sent for palmer.
# Response code 200 received for palmer.
# Request 413 sent for leningradskiy.
# Response code 200 received for leningradskiy.
# Request 414 sent for youhao.
# Response code 200 received for youhao.
# himora does not exist in OpenWeatherMap.
# Request 416 sent for baijiantan.
# Response code 200 received for baijiantan.
# Request 417 sent for wuning.
# Response code 200 received for wuning.
# Request 418 sent for cairns.
# Response code 200 received for cairns.
# Request 419 sent for jinchang.
# Response code 200 received for jinchang.
# temaraia does not exist in OpenWeatherMap.
# Request 421 sent for astoria.
# Response code 200 received for astoria.
# Request 422 sent for largo.
# Response code 200 received for largo.
# Request 423 sent for inza.
# Response code 200 received for inza.
# Request 424 sent for bubaque.
# Response code 200 received for bubaque.
# qabis does not exist in OpenWeatherMap.
# Request 426 sent for ponta delgada.
# Response code 200 received for ponta delgada.
# Request 427 sent for vestmannaeyjar.
# Response code 200 received for vestmannaeyjar.
# Request 428 sent for chapais.
# Response code 200 received for chapais.
# Request 429 sent for tautira.
# Response code 200 received for tautira.
# Request 430 sent for alyangula.
# Response code 200 received for alyangula.
# Request 431 sent for laguna.
# Response code 200 received for laguna.
# Request 432 sent for araouane.
# Response code 200 received for araouane.
# Request 433 sent for comodoro rivadavia.
# Response code 200 received for comodoro rivadavia.
# Request 434 sent for nouadhibou.
# Response code 200 received for nouadhibou.
# mahaicony does not exist in OpenWeatherMap.
# Request 436 sent for sao felix do xingu.
# Response code 200 received for sao felix do xingu.
# Request 437 sent for barra patuca.
# Response code 200 received for barra patuca.
# Request 438 sent for maragheh.
# Response code 200 received for maragheh.
# Request 439 sent for okhotsk.
# Response code 200 received for okhotsk.
# Request 440 sent for illela.
# Response code 200 received for illela.
# Request 441 sent for saint george.
# Response code 200 received for saint george.
# Request 442 sent for shitanjing.
# Response code 200 received for shitanjing.
# Request 443 sent for pundaguitan.
# Response code 200 received for pundaguitan.
# Request 444 sent for husavik.
# Response code 200 received for husavik.
# Request 445 sent for acamixtla.
# Response code 200 received for acamixtla.
# Request 446 sent for rochegda.
# Response code 200 received for rochegda.
# Request 447 sent for danielskuil.
# Response code 200 received for danielskuil.
# Request 448 sent for bakel.
# Response code 200 received for bakel.
# Request 449 sent for soyo.
# Response code 200 received for soyo.
# Request 450 sent for antalaha.
# Response code 200 received for antalaha.
# Request 451 sent for port keats.
# Response code 200 received for port keats.
# Request 452 sent for constantine.
# Response code 200 received for constantine.
# Request 453 sent for lagoa.
# Response code 200 received for lagoa.
# Request 454 sent for togur.
# Response code 200 received for togur.
# Request 455 sent for athabasca.
# Response code 200 received for athabasca.
# Request 456 sent for klaksvik.
# Response code 200 received for klaksvik.
# Request 457 sent for emet.
# Response code 200 received for emet.
# Request 458 sent for narsaq.
# Response code 200 received for narsaq.
# Request 459 sent for berdigestyakh.
# Response code 200 received for berdigestyakh.
# Request 460 sent for warmbad.
# Response code 200 received for warmbad.
# Request 461 sent for richards bay.
# Response code 200 received for richards bay.
# Request 462 sent for yarada.
# Response code 200 received for yarada.
# Request 463 sent for nazarovo.
# Response code 200 received for nazarovo.
# Request 464 sent for loandjili.
# Response code 200 received for loandjili.
# Request 465 sent for saint-augustin.
# Response code 200 received for saint-augustin.
# Request 466 sent for guadalupe y calvo.
# Response code 200 received for guadalupe y calvo.
# Request 467 sent for lebane.
# Response code 200 received for lebane.
# Request 468 sent for sulangan.
# Response code 200 received for sulangan.
# Request 469 sent for flin flon.
# Response code 200 received for flin flon.
# Request 470 sent for gizo.
# Response code 200 received for gizo.
# Request 471 sent for langsa.
# Response code 200 received for langsa.
# Request 472 sent for biak.
# Response code 200 received for biak.
# Request 473 sent for manado.
# Response code 200 received for manado.
# Request 474 sent for catalina.
# Response code 200 received for catalina.
# Request 475 sent for konigs wusterhausen.
# Response code 200 received for konigs wusterhausen.
# Request 476 sent for mattru.
# Response code 200 received for mattru.
# Request 477 sent for burley.
# Response code 200 received for burley.
# Request 478 sent for mwinilunga.
# Response code 200 received for mwinilunga.
# Request 479 sent for sunrise manor.
# Response code 200 received for sunrise manor.
# Request 480 sent for concarneau.
# Response code 200 received for concarneau.
# Request 481 sent for sindou.
# Response code 200 received for sindou.
# Request 482 sent for shenzhen.
# Response code 200 received for shenzhen.
# tabiauea does not exist in OpenWeatherMap.
# Request 484 sent for gat.
# Response code 200 received for gat.
# Request 485 sent for kalavai.
# Response code 200 received for kalavai.
# karaul does not exist in OpenWeatherMap.
# Request 487 sent for oliveira.
# Response code 200 received for oliveira.
# Request 488 sent for ishikari.
# Response code 200 received for ishikari.
# Request 489 sent for intipuca.
# Response code 200 received for intipuca.
# Request 490 sent for hami.
# Response code 200 received for hami.
# ust-kamchatsk does not exist in OpenWeatherMap.
# yanchukan does not exist in OpenWeatherMap.
# Request 493 sent for kashan.
# Response code 200 received for kashan.
# Request 494 sent for narrabri.
# Response code 200 received for narrabri.
# Request 495 sent for nishihara.
# Response code 200 received for nishihara.
# Request 496 sent for cockburn town.
# Response code 200 received for cockburn town.
# Request 497 sent for loubomo.
# Response code 200 received for loubomo.
# Request 498 sent for ukhta.
# Response code 200 received for ukhta.
# Request 499 sent for suntar.
# Response code 200 received for suntar.
# Request 500 sent for bontang.
# Response code 200 received for bontang.
# Request 501 sent for colombo.
# Response code 200 received for colombo.
# Request 502 sent for fairbanks.
# Response code 200 received for fairbanks.
# Request 503 sent for copperas cove.
# Response code 200 received for copperas cove.
# Request 504 sent for igrim.
# Response code 200 received for igrim.
# Request 505 sent for portland.
# Response code 200 received for portland.
# Request 506 sent for codrington.
# Response code 200 received for codrington.
# Request 507 sent for atascadero.
# Response code 200 received for atascadero.
# bolungarvik does not exist in OpenWeatherMap.
# Request 509 sent for eskisehir.
# Response code 200 received for eskisehir.
# Request 510 sent for porto novo.
# Response code 200 received for porto novo.
# Request 511 sent for dehui.
# Response code 200 received for dehui.
# Request 512 sent for sao joao da barra.
# Response code 200 received for sao joao da barra.
# bababe does not exist in OpenWeatherMap.
# Request 514 sent for luangwa.
# Response code 200 received for luangwa.
# Request 515 sent for ambovombe.
# Response code 200 received for ambovombe.
# Request 516 sent for teya.
# Response code 200 received for teya.
# Request 517 sent for bandrele.
# Response code 200 received for bandrele.
# Request 518 sent for clinton.
# Response code 200 received for clinton.
# Request 519 sent for kalachinsk.
# Response code 200 received for kalachinsk.
# Request 520 sent for kargasok.
# Response code 200 received for kargasok.
# Request 521 sent for seoul.
# Response code 200 received for seoul.
# Request 522 sent for pemba.
# Response code 200 received for pemba.
# Request 523 sent for pitimbu.
# Response code 200 received for pitimbu.
# Request 524 sent for bonfim.
# Response code 200 received for bonfim.
# Request 525 sent for santa maria.
# Response code 200 received for santa maria.
# Request 526 sent for la fria.
# Response code 200 received for la fria.
# Request 527 sent for kapuskasing.
# Response code 200 received for kapuskasing.
# solsvik does not exist in OpenWeatherMap.
# Request 529 sent for balkanabat.
# Response code 200 received for balkanabat.
# Request 530 sent for vao.
# Response code 200 received for vao.
# Request 531 sent for morondava.
# Response code 200 received for morondava.
# gurgan does not exist in OpenWeatherMap.
# Request 533 sent for tessalit.
# Response code 200 received for tessalit.
# karkaralinsk does not exist in OpenWeatherMap.
# Request 535 sent for tocopilla.
# Response code 200 received for tocopilla.
# Request 536 sent for taksimo.
# Response code 200 received for taksimo.
# Request 537 sent for los llanos de aridane.
# Response code 200 received for los llanos de aridane.
# Request 538 sent for vanimo.
# Response code 200 received for vanimo.
# Request 539 sent for dubna.
# Response code 200 received for dubna.
# Request 540 sent for oriximina.
# Response code 200 received for oriximina.
# Request 541 sent for trat.
# Response code 200 received for trat.
# Request 542 sent for kununurra.
# Response code 200 received for kununurra.
# Request 543 sent for wloclawek.
# Response code 200 received for wloclawek.
# Request 544 sent for bilma.
# Response code 200 received for bilma.
# Request 545 sent for yerkoy.
# Response code 200 received for yerkoy.
# Request 546 sent for yanaul.
# Response code 200 received for yanaul.
# Request 547 sent for baghdad.
# Response code 200 received for baghdad.
# Request 548 sent for carutapera.
# Response code 200 received for carutapera.
# Request 549 sent for kampen.
# Response code 200 received for kampen.
# Request 550 sent for dutlwe.
# Response code 200 received for dutlwe.
# Request 551 sent for abalak.
# Response code 200 received for abalak.
# Request 552 sent for tarko-sale.
# Response code 200 received for tarko-sale.
# Request 553 sent for igarka.
# Response code 200 received for igarka.
# Request 554 sent for yangjiang.
# Response code 200 received for yangjiang.
# Request 555 sent for lavrentiya.
# Response code 200 received for lavrentiya.
# Request 556 sent for leeton.
# Response code 200 received for leeton.
# karamea does not exist in OpenWeatherMap.
# Request 558 sent for montrose.
# Response code 200 received for montrose.
# Request 559 sent for dobrinka.
# Response code 200 received for dobrinka.
# Request 560 sent for hervey bay.
# Response code 200 received for hervey bay.
# Request 561 sent for maumere.
# Response code 200 received for maumere.
# Request 562 sent for krasnokamensk.
# Response code 200 received for krasnokamensk.
# Request 563 sent for herat.
# Response code 200 received for herat.
# Request 564 sent for yining.
# Response code 200 received for yining.
# Request 565 sent for marawi.
# Response code 200 received for marawi.
# Request 566 sent for olafsvik.
# Response code 200 received for olafsvik.
# Request 567 sent for roma.
# Response code 200 received for roma.
# Request 568 sent for caravelas.
# Response code 200 received for caravelas.
# Request 569 sent for namibe.
# Response code 200 received for namibe.
# Request 570 sent for balkhash.
# Response code 200 received for balkhash.
# Request 571 sent for berbera.
# Response code 200 received for berbera.
# Request 572 sent for havelock.
# Response code 200 received for havelock.
# Request 573 sent for lubango.
# Response code 200 received for lubango.
# Request 574 sent for olovyannaya.
# Response code 200 received for olovyannaya.
# Request 575 sent for san cristobal.
# Response code 200 received for san cristobal.
# Request 576 sent for umm kaddadah.
# Response code 200 received for umm kaddadah.
# Request 577 sent for harnosand.
# Response code 200 received for harnosand.
# Request 578 sent for kiama.
# Response code 200 received for kiama.
# Request 579 sent for patacamaya.
# Response code 200 received for patacamaya.
# Request 580 sent for kokkola.
# Response code 200 received for kokkola.
# Request 581 sent for gunjur.
# Response code 200 received for gunjur.
# Request 582 sent for santa helena.
# Response code 200 received for santa helena.
# Request 583 sent for samarai.
# Response code 200 received for samarai.
# Request 584 sent for serebryansk.
# Response code 200 received for serebryansk.
# kazalinsk does not exist in OpenWeatherMap.
# Request 586 sent for khani.
# Response code 200 received for khani.
# Request 587 sent for livny.
# Response code 200 received for livny.
# Request 588 sent for mangochi.
# Response code 200 received for mangochi.
# Request 589 sent for petawawa.
# Response code 200 received for petawawa.
# Request 590 sent for yar-sale.
# Response code 200 received for yar-sale.
# Request 591 sent for alice springs.
# Response code 200 received for alice springs.
# Request 592 sent for fayaoue.
# Response code 200 received for fayaoue.
# Request 593 sent for nueva guinea.
# Response code 200 received for nueva guinea.
# Request 594 sent for mount gambier.
# Response code 200 received for mount gambier.
# Request 595 sent for high level.
# Response code 200 received for high level.
# Request 596 sent for banjar.
# Response code 200 received for banjar.
# Request 597 sent for bonavista.
# Response code 200 received for bonavista.
# Request 598 sent for grenville.
# Response code 200 received for grenville.
# Request 599 sent for anshun.
# Response code 200 received for anshun.
# Request 600 sent for puerto lleras.
# Response code 200 received for puerto lleras.
# Request 601 sent for prince rupert.
# Response code 200 received for prince rupert.
# Request 602 sent for padang.
# Response code 200 received for padang.
# Request 603 sent for mikuni.
# Response code 200 received for mikuni.
# Request 604 sent for meulaboh.
# Response code 200 received for meulaboh.
# Request 605 sent for tooele.
# Response code 200 received for tooele.
# Request 606 sent for noginsk.
# Response code 200 received for noginsk.
# Request 607 sent for puerto leguizamo.
# Response code 200 received for puerto leguizamo.
# Request 608 sent for klyuchi.
# Response code 200 received for klyuchi.
# Request 609 sent for nassau.
# Response code 200 received for nassau.
# Request 610 sent for aykhal.
# Response code 200 received for aykhal.
# Request 611 sent for faya.
# Response code 200 received for faya.
# Request 612 sent for hastings.
# Response code 200 received for hastings.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_dict ={"city": city1, "latitude": lat, "longitude": long, "Max Temp": max_temp,
                   "humidity": humid, "Feels Like": temp, "cloudiness": clouds, "wind speed": winds,
                   "country": country, "datetime": datetime}

# %%
city_weather = pd.DataFrame(city_weather_dict)
city_weather.head()
# Out:
#         city  latitude  longitude  Max Temp  humidity  Feels Like  cloudiness  \
# 0    Rikitea  -23.1203  -134.9692     70.52        69       70.52           1
# 1  Busselton  -33.6500   115.3333     60.67        50       58.78           1
# 2  Hithadhoo   -0.6000    73.0833     81.73        77       87.46          87
# 3   Thompson   55.7435   -97.8558     51.96        82       50.72           0
# 4   Tasiilaq   65.6145   -37.6368     41.16        78       37.42          16
#
#    wind speed country    datetime
# 0       12.30      PF  1661237341
# 1        6.73      AU  1661237341
# 2       15.08      MV  1661237342
# 3        2.30      CA  1661237201
# 4        5.59      GL  1661237342

# %%
# unix, UTC timestamp conversion from:
# https://www.codegrepper.com/code-examples/python/convert+unix+timestamp+to+datetime+python+pandas
city_weather["date"] = pd.to_datetime(city_weather["datetime"], unit="s").dt.tz_localize("US/Pacific")

city_weather.head()
# Out:
#         city  latitude  longitude  Max Temp  humidity  Feels Like  cloudiness  \
# 0    Rikitea  -23.1203  -134.9692     70.52        69       70.52           1
# 1  Busselton  -33.6500   115.3333     60.67        50       58.78           1
# 2  Hithadhoo   -0.6000    73.0833     81.73        77       87.46          87
# 3   Thompson   55.7435   -97.8558     51.96        82       50.72           0
# 4   Tasiilaq   65.6145   -37.6368     41.16        78       37.42          16
#
#    wind speed country    datetime                      date
# 0       12.30      PF  1661237341 2022-08-23 06:49:01-07:00
# 1        6.73      AU  1661237341 2022-08-23 06:49:01-07:00
# 2       15.08      MV  1661237342 2022-08-23 06:49:02-07:00
# 3        2.30      CA  1661237201 2022-08-23 06:46:41-07:00
# 4        5.59      GL  1661237342 2022-08-23 06:49:02-07:00

# %%
# found country converter to convert from ISO 2 letter country to country name at the following"
# https://pypi.org/project/country-converter/
# https://stackoverflow.com/questions/64051741/how-to-convert-country-code-to-name-with-country-converter-in-pandas
# https://notebook.community/konstantinstadler/country_converter/doc/country_converter_examples
converter = coco.CountryConverter()
city_weather["country name"] = converter.convert(city_weather["country"], src="ISO2", to="name_short")

# %%
city_weather.head()
# Out:
#         city  latitude  longitude  Max Temp  humidity  Feels Like  cloudiness  \
# 0    Rikitea  -23.1203  -134.9692     70.52        69       70.52           1
# 1  Busselton  -33.6500   115.3333     60.67        50       58.78           1
# 2  Hithadhoo   -0.6000    73.0833     81.73        77       87.46          87
# 3   Thompson   55.7435   -97.8558     51.96        82       50.72           0
# 4   Tasiilaq   65.6145   -37.6368     41.16        78       37.42          16
#
#    wind speed country    datetime                      date      country name
# 0       12.30      PF  1661237341 2022-08-23 06:49:01-07:00  French Polynesia
# 1        6.73      AU  1661237341 2022-08-23 06:49:01-07:00         Australia
# 2       15.08      MV  1661237342 2022-08-23 06:49:02-07:00          Maldives
# 3        2.30      CA  1661237201 2022-08-23 06:46:41-07:00            Canada
# 4        5.59      GL  1661237342 2022-08-23 06:49:02-07:00         Greenland

# %%
city_weather2 = city_weather[["city", "latitude", "longitude", "Max Temp", "humidity",
                             "Feels Like", "cloudiness", "wind speed", "country name",
                             "date"]] 
city_weather2.head()
# Out:
#         city  latitude  longitude  Max Temp  humidity  Feels Like  cloudiness  \
# 0    Rikitea  -23.1203  -134.9692     70.52        69       70.52           1
# 1  Busselton  -33.6500   115.3333     60.67        50       58.78           1
# 2  Hithadhoo   -0.6000    73.0833     81.73        77       87.46          87
# 3   Thompson   55.7435   -97.8558     51.96        82       50.72           0
# 4   Tasiilaq   65.6145   -37.6368     41.16        78       37.42          16
#
#    wind speed      country name                      date
# 0       12.30  French Polynesia 2022-08-23 06:49:01-07:00
# 1        6.73         Australia 2022-08-23 06:49:01-07:00
# 2       15.08          Maldives 2022-08-23 06:49:02-07:00
# 3        2.30            Canada 2022-08-23 06:46:41-07:00
# 4        5.59         Greenland 2022-08-23 06:49:02-07:00

# %%
city_weather2.to_csv("fresh_vacation_output_data/cities.csv")
len(city_weather2)
# Out:
# 562

# %%
request_response_dict = {"city": city1, "request sent": print_request, "response received": print_response}
request_response = pd.DataFrame(request_response_dict)
request_response.head()
# Out:
#         city                   request sent  \
# 0    Rikitea    Request 1 sent for rikitea.
# 1  Busselton  Request 2 sent for busselton.
# 2  Hithadhoo  Request 3 sent for hithadhoo.
# 3   Thompson   Request 4 sent for thompson.
# 4   Tasiilaq   Request 5 sent for tasiilaq.
#
#                            response received
# 0    Response code 200 received for rikitea.
# 1  Response code 200 received for busselton.
# 2  Response code 200 received for hithadhoo.
# 3   Response code 200 received for thompson.
# 4   Response code 200 received for tasiilaq.

# %%
request_response.to_csv("fresh_vacation_output_data/request_response_log.csv", index=False)
len(request_response)
# Out:
# 562

# %%
city_dne_dict = {"city": city2, "response received": print_dne}
city_dne = pd.DataFrame(city_dne_dict)
city_dne.head()
# Out:
#                      city                                  response received
# 0               skalistyy        skalistyy does not exist in OpenWeatherMap.
# 1        illoqqortoormiut  illoqqortoormiut does not exist in OpenWeather...
# 2  grand river south east  grand river south east does not exist in OpenW...
# 3            attawapiskat     attawapiskat does not exist in OpenWeatherMap.
# 4             nizhneyansk      nizhneyansk does not exist in OpenWeatherMap.

# %%
city_dne.to_csv("fresh_vacation_output_data/response_error_log.csv", index=False)

len(city_dne)
# Out:
# 51

# %% [markdown]
# ## Narrow down the DataFrame to find your ideal weather condition. For example:
# - A max temperature lower than 80 degrees but higher than 70.
# - Wind speed less than 10 mph.
# - Zero cloudiness.
# - Drop any rows that don't satisfy all three conditions. You want to be sure the weather is ideal.
# ----
# - **Note:** Feel free to adjust your specifications, but make sure to limit the number of rows returned by your API requests to a reasonable number.
# - Try to reduce the results in your DataFrame to 10 or fewer cities.

# %%
# Using Feels Like temperature since it considers humidity and temperature together in a Heat Index.
# Running this .loc with Feels Like > 70 degrees and < 8 degrees.
# With latitude between -30 degrees South and 30 degrees North.  "Some place tropical."
# With cloudiness < 25% and winds less than 10  mph.
# Adjust humidity percent until get to 10 or less results.
ideal_feels = city_weather2.loc[(city_weather2["Feels Like"] > 70) & (city_weather2["Feels Like"] < 80), :]
ideal_clouds = ideal_feels.loc[(ideal_feels["cloudiness"] == 0), :]
ideal_winds = ideal_clouds.loc[(ideal_clouds["wind speed"] < 10), :]
ideal = ideal_winds.reset_index(drop=True)
ideal
# Out:
#             city  latitude  longitude  Max Temp  humidity  Feels Like  \
# 0          Cabra   37.4725    -4.4421     71.65        52       70.97
# 1         Emmett   43.8735  -116.4993     80.49        47       73.08
# 2       Moranbah  -22.0016   148.0466     76.93        33       75.87
# 3           Elko   41.0002  -115.5012     72.64        13       70.20
# 4       Bugul'ma   54.5500    52.8000     80.26        36       79.79
# 5          Houma   29.5958   -90.7195     78.01        96       78.91
# 6        Russell   32.3502   -85.1999     74.01       100       74.37
# 7         Palmas  -10.2128   -48.3603     76.87        44       76.33
# 8          Bahār   34.9072    48.4414     78.96        19       78.96
# 9   Saint-Pierre  -21.3393    55.4781     80.28        53       78.03
# 10  Vangaindrano  -23.3500    47.6000     72.59        70       72.84
# 11       Marfino   55.7028    37.3822     76.95        50       74.43
# 12         Largo   27.9095   -82.7873     82.40        81       79.79
# 13        Laguna   38.4210  -121.4238     78.31        68       73.56
# 14   Constantine   36.3650     6.6147     72.81        53       72.28
# 15          Emet   39.3430    29.2585     78.13        53       78.13
# 16         Igrim   63.1906    64.4162     77.85        41       77.25
# 17    Atascadero   35.4894  -120.6707     75.00        56       71.55
#
#     cloudiness  wind speed   country name                      date
# 0            0        2.53          Spain 2022-08-23 06:49:04-07:00
# 1            0        5.46  United States 2022-08-23 06:49:07-07:00
# 2            0        8.46      Australia 2022-08-23 06:49:13-07:00
# 3            0        5.01  United States 2022-08-23 06:49:31-07:00
# 4            0        7.31         Russia 2022-08-23 06:48:02-07:00
# 5            0        0.00  United States 2022-08-23 06:50:01-07:00
# 6            0        0.00  United States 2022-08-23 06:50:31-07:00
# 7            0        8.05         Brazil 2022-08-23 06:50:47-07:00
# 8            0        4.61           Iran 2022-08-23 06:50:54-07:00
# 9            0        3.44        Reunion 2022-08-23 06:50:59-07:00
# 10           0        4.03     Madagascar 2022-08-23 06:51:36-07:00
# 11           0        6.71         Russia 2022-08-23 06:51:43-07:00
# 12           0        4.61  United States 2022-08-23 06:51:57-07:00
# 13           0        4.61  United States 2022-08-23 06:52:01-07:00
# 14           0        0.00        Algeria 2022-08-23 06:52:10-07:00
# 15           0        2.24         Turkey 2022-08-23 06:52:12-07:00
# 16           0        5.91         Russia 2022-08-23 06:52:32-07:00
# 17           0        3.62  United States 2022-08-23 06:52:33-07:00

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * You must take a screenshot of the heatmap that you create and include it in your submission
# * Google Maps
# ------
# * Use Google Places API to find the first hotel for each city located within 5,000 meters of your coordinates.
# * Plot the hotels on top of the humidity heatmap, with each pin containing the **Hotel Name**, **City**, and **Country**.
# * A heatmap is successfully created.
# * For max intensity in the heatmap, try setting it to the highest humidity found in the dataset.
# * Ten or less pins for all the cities in the DataFrame.
# * Pins are clickable to display City, Country and Hotel Name.
# * Placed on top of the heatmap.

# %% [markdown]
# ## Humidity Heatmap

# %%
# Store latitude and longitude in locations
locations = ideal_winds[["latitude", "longitude"]]
len(locations)
# Out:
# 18

# %%
humid = ideal_winds["humidity"]
#humid
#type(humid)
#len(humid)
max_humid = humid.max()
max_humid
# Out:
# 100

# %%
# Customize the size of the map
figure_layout = {
    'width': '80%',
    'margin': '0 auto 0 auto',
    'padding': '1px',
    'border': '1px solid black'
}

# Plot Heatmap
fig = gmaps.figure(layout=figure_layout, map_type='SATELLITE',
                  zoom_level=2, center=(30.267, -97.743),
                  display_toolbar=False)

# I TURNED OFF display_toolbar IN ORDER TO DOWNLOAD A PNG OF THE HEATMAP.  I TURNED IT BACK ON BEFORE I FILED.

# Create heatmap layer
heatmap_layer = gmaps.heatmap_layer(locations, weights=humid,
                                dissipating=False, max_intensity=max_humid,
                                point_radius=5, opacity = 1.0)

# Add layer
fig.add_layer(heatmap_layer)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='420px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### If I say lived in a cruddy climate, where it was windy and rainy all of the time, and I wanted to travel somewhere with ideal weather right now, I might define the location based on ideal weather conditions consisting of cloudless days, winds less than 10 mph, and the temperature is between 70 and 80 degrees Fahrenheit.  Someone wants to make my dream come true, but I can only choose from a list of 500 - 600 randomly selected cities anywhere in the world before I apply my weather conditions.  As it turns out, I only get to choose from the 10 results shown on the heatmap, and the list started with 586 cities!

# %% [markdown]
# ### This heatmap is based on humidity with the city in Japan having the highest intensity, and the city in Argentina having the lowest intensity.

# %% [markdown]
# ## Humidity Heatmap with Markers

# %%
# Store city and country name in location_name
location_name = ideal_winds[["city", "country name"]]
#type(location_name)
#print(location_name)

# %%
# set up additional columns to hold results from requests
#places = locations[["latitude", "longitude"]]
#places.loc[index, "name"] = ""
#places.loc[index, "address"] = ""
#places.loc[index, "rating"] = ""
#places.head()

# %%
# geocoordinates
# use locations list
#target_search = "hotel"
#target_radius = 5000
#target_type = "lodging"
#target_ranking = "rankby"

#            # set up a parameters dictionary
#
#            #    "keyword": "hotel",
#            params = {
#                "radius": 1000,
#                "type": "lodging",
#                "key": gkey
#            }
#            #    "keyword": target_search,
#
#
#
#            # use iterrows to iterate through the locations DataFrame
#            for index, row in places.iterrows():
#                # get lat, lng from df
#                lat = row["latitude"]
#                lng = row["longitude"]
#
#                # change location each iteration while leaving original params in place
#                params["location"] = f"{lat},{lng}"
#
#                # Use the search term: "hotel" and our lat/lng
#                base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#
#                # base url and API requests
#                print(f"Retrieving Results for Index {index}: {locations}.")
#                hotel_name = requests.get(base_url, params=params)
#
#                # find lodging within 5000 meters of the city center
#                # extract results
#                hotel_name = hotel_name.json()
#
#                # use try-except to clear any exceptions
#                try:
#                    #print(f"Lodging available is {hotel_name["results"][0]["name"]}.")
#
#                    places.loc[index, "name"] = hotel_name["results"][0]["name"]
#                    places.loc[index, "address"] = hotel_name["results"][0]["vicinity"]
#                    #places.loc[index, "price_level"] = hotel_name["results"][0]["price_level"]
#                    places.loc[index, "rating"] = hotel_name["results"][0]["rating"]
#
#                except (KeyError, IndexError):
#                    print("Missing field/result... skipping.")
#
#                print("------------")
#
#
#            
# NEED MORE TIME TO GET THIS CODE BLOCK TO WORK.  LARGE INDENTS ARE FOR THE CODE THAT NEEDS TO BE ADJUSTED.

# %%
# check response url 
# !!!!!!!COMMENT OUT THIS PRINT STATEMENT SO OUTPUT WITH THE API KEY IS NOT EXPOSED WHEN COMMIT TO GITHUB!!!!
#print(response.url)

# %%
# Converting response to json
# places_data = response.json()

# %%
# Print the json to see results
#print(json.dumps(hotel_name, indent=4, sort_keys=True))
#pprint(hotel_name)
# THIS WORKS, BUT I ONLY GET THE RESULTS FOR THE LAST CITY LOCATION.  NEED TO ADJUST LOOP IN CODE BLOCK ABOVE.

# %%
test_city = ideal_winds["city"].tolist()
test_country = ideal_winds["country name"].tolist()
city_country = list(zip(test_city, test_country))
#print(city_country)

# %%
# Customize the size of the map
figure_layout = {
    'width': '80%',
    'margin': '0 auto 0 auto',
    'padding': '1px',
    'border': '1px solid black'
}

# Plot Heatmap
fig = gmaps.figure(layout=figure_layout, map_type='SATELLITE',
                  zoom_level=2, center=(30.267, -97.743),
                  display_toolbar=False)
# I TURNED OFF display_toolbar IN ORDER TO DOWNLOAD A PNG OF THE HEATMAP.  I TURNED IT BACK ON BEFORE I FILED.

# Create heatmap layer
heatmap_layer = gmaps.heatmap_layer(locations, weights=humid,
                                dissipating=False, max_intensity=max_humid,
                                point_radius=5, opacity = 1.0)

# Assign the marker layer to markers
markers = gmaps.marker_layer(locations,
                            display_info_box=True,
                            info_box_content=test_city,
                            hover_text=test_city)
                             
#                            hover_text=['Nantucket', 'Terrace', 'Hibbing', 'Havre-St-Pierre', 'Libertador General San Martín', 'Vermillion',
#         'Tacuatí', 'Jadu', 'Korčula', 'Wajima'])

#hover_text="bluh\nbluh\nbluh")

# Add the layer to the map
fig.add_layer(markers)



# Add layer
fig.add_layer(heatmap_layer)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='420px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Well, if I would at least want to know if there is a hotel in each of these cities.

# %% [markdown]
# ### Markers are clickable, but they only have the city name right now.  Hover_text also works, but only with city name so far.
# -------
#
# ### I need to spend more time on the code block for the Google Places nearbyseach API results to get the markers to fully function with city, country, hotel.
