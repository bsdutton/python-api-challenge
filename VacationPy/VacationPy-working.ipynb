# %% [markdown]
# # VacationPy
# ----
#
# #### Create a heat map that displays the humidity for every city from WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from pprint import pprint
import country_converter as coco
from scipy import stats
import gmaps

# Import API key
from api_keys import weather_api_key
from config import gkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# configure Gmaps
gmaps.configure(api_key=gkey)
fig = gmaps.figure()

# Output File (CSV)
output_data_file = "vacation_output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Re-Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 643

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build the query for the for-loop
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
lat = []
long = []
temp = []
humid = []
clouds = []
winds = []
city1 = []
city2 = []
max_temp = []
country = []
datetime = []
print_request = []
print_response = []
print_dne = []

# %%
# Loops work on smaller range.  Reset and empty list by running codeblock where they created.
# Run loops and monitor print outputs.

# %%
for city in range(len(cities)):
    try:
        weather2 = requests.get(query_url + str(cities[city])).json()
        lat.append(weather2['coord']['lat'])
        long.append(weather2['coord']['lon'])
        temp.append(weather2['main']['feels_like'])
        max_temp.append(weather2['main']['temp_max'])
        humid.append(weather2['main']['humidity'])
        clouds.append(weather2['clouds']['all'])
        winds.append(weather2['wind']['speed'])
        city1.append(weather2['name'])
        country.append(weather2['sys']['country'])
        datetime.append(weather2['dt'])
        print(f"Request {city} sent for {cities[city]}.")
        print_request.append(f"Request {city} sent for {cities[city]}.")
        print(f"Response code {weather2['cod']} received for {cities[city]}.")
        print_response.append(f"Response code {weather2['cod']} received for {cities[city]}.")
    except:
        print(f"{cities[city]} does not exist in OpenWeatherMap.")
        city2.append(cities[city])
        print_dne.append(f"{cities[city]} does not exist in OpenWeatherMap.")
        pass
# Out:
# Request 0 sent for fatehpur.
# Response code 200 received for fatehpur.
# Request 1 sent for jamestown.
# Response code 200 received for jamestown.
# Request 2 sent for ushuaia.
# Response code 200 received for ushuaia.
# belushya guba does not exist in OpenWeatherMap.
# Request 4 sent for castro.
# Response code 200 received for castro.
# Request 5 sent for chokurdakh.
# Response code 200 received for chokurdakh.
# Request 6 sent for quatre cocos.
# Response code 200 received for quatre cocos.
# Request 7 sent for butaritari.
# Response code 200 received for butaritari.
# Request 8 sent for athabasca.
# Response code 200 received for athabasca.
# Request 9 sent for rikitea.
# Response code 200 received for rikitea.
# Request 10 sent for saint-francois.
# Response code 200 received for saint-francois.
# Request 11 sent for busselton.
# Response code 200 received for busselton.
# Request 12 sent for spassk-ryazanskiy.
# Response code 200 received for spassk-ryazanskiy.
# Request 13 sent for punta arenas.
# Response code 200 received for punta arenas.
# Request 14 sent for thunder bay.
# Response code 200 received for thunder bay.
# Request 15 sent for kapaa.
# Response code 200 received for kapaa.
# illoqqortoormiut does not exist in OpenWeatherMap.
# Request 17 sent for victoria.
# Response code 200 received for victoria.
# Request 18 sent for atuona.
# Response code 200 received for atuona.
# Request 19 sent for bredasdorp.
# Response code 200 received for bredasdorp.
# taolanaro does not exist in OpenWeatherMap.
# Request 21 sent for brodick.
# Response code 200 received for brodick.
# Request 22 sent for chernyshevskiy.
# Response code 200 received for chernyshevskiy.
# Request 23 sent for mahebourg.
# Response code 200 received for mahebourg.
# Request 24 sent for mogadishu.
# Response code 200 received for mogadishu.
# Request 25 sent for yellowknife.
# Response code 200 received for yellowknife.
# Request 26 sent for padang.
# Response code 200 received for padang.
# nizhneyansk does not exist in OpenWeatherMap.
# Request 28 sent for comodoro rivadavia.
# Response code 200 received for comodoro rivadavia.
# umzimvubu does not exist in OpenWeatherMap.
# Request 30 sent for port hedland.
# Response code 200 received for port hedland.
# Request 31 sent for maniitsoq.
# Response code 200 received for maniitsoq.
# Request 32 sent for veselynove.
# Response code 200 received for veselynove.
# Request 33 sent for bethel.
# Response code 200 received for bethel.
# Request 34 sent for sangar.
# Response code 200 received for sangar.
# Request 35 sent for hobart.
# Response code 200 received for hobart.
# Request 36 sent for albany.
# Response code 200 received for albany.
# Request 37 sent for anchorage.
# Response code 200 received for anchorage.
# Request 38 sent for port alfred.
# Response code 200 received for port alfred.
# Request 39 sent for yulara.
# Response code 200 received for yulara.
# Request 40 sent for ballina.
# Response code 200 received for ballina.
# Request 41 sent for upernavik.
# Response code 200 received for upernavik.
# Request 42 sent for porto de moz.
# Response code 200 received for porto de moz.
# Request 43 sent for lompoc.
# Response code 200 received for lompoc.
# Request 44 sent for bluff.
# Response code 200 received for bluff.
# Request 45 sent for lebu.
# Response code 200 received for lebu.
# barentsburg does not exist in OpenWeatherMap.
# Request 47 sent for san cristobal.
# Response code 200 received for san cristobal.
# Request 48 sent for medeiros neto.
# Response code 200 received for medeiros neto.
# Request 49 sent for bay saint louis.
# Response code 200 received for bay saint louis.
# Request 50 sent for tahara.
# Response code 200 received for tahara.
# Request 51 sent for grindavik.
# Response code 200 received for grindavik.
# Request 52 sent for orocue.
# Response code 200 received for orocue.
# Request 53 sent for mataura.
# Response code 200 received for mataura.
# Request 54 sent for san policarpo.
# Response code 200 received for san policarpo.
# Request 55 sent for lomas de sargentillo.
# Response code 200 received for lomas de sargentillo.
# Request 56 sent for dickinson.
# Response code 200 received for dickinson.
# Request 57 sent for kavieng.
# Response code 200 received for kavieng.
# Request 58 sent for maumere.
# Response code 200 received for maumere.
# Request 59 sent for hithadhoo.
# Response code 200 received for hithadhoo.
# Request 60 sent for kavaratti.
# Response code 200 received for kavaratti.
# Request 61 sent for mehamn.
# Response code 200 received for mehamn.
# Request 62 sent for avarua.
# Response code 200 received for avarua.
# Request 63 sent for carnarvon.
# Response code 200 received for carnarvon.
# Request 64 sent for sao gabriel da cachoeira.
# Response code 200 received for sao gabriel da cachoeira.
# Request 65 sent for leh.
# Response code 200 received for leh.
# Request 66 sent for saskylakh.
# Response code 200 received for saskylakh.
# Request 67 sent for new norfolk.
# Response code 200 received for new norfolk.
# Request 68 sent for miranda.
# Response code 200 received for miranda.
# khonuu does not exist in OpenWeatherMap.
# Request 70 sent for georgetown.
# Response code 200 received for georgetown.
# amderma does not exist in OpenWeatherMap.
# Request 72 sent for rabo de peixe.
# Response code 200 received for rabo de peixe.
# Request 73 sent for ostrovnoy.
# Response code 200 received for ostrovnoy.
# Request 74 sent for cidreira.
# Response code 200 received for cidreira.
# Request 75 sent for ardino.
# Response code 200 received for ardino.
# Request 76 sent for estelle.
# Response code 200 received for estelle.
# tsihombe does not exist in OpenWeatherMap.
# Request 78 sent for naze.
# Response code 200 received for naze.
# Request 79 sent for port elizabeth.
# Response code 200 received for port elizabeth.
# Request 80 sent for bukachacha.
# Response code 200 received for bukachacha.
# Request 81 sent for torbay.
# Response code 200 received for torbay.
# Request 82 sent for kaitangata.
# Response code 200 received for kaitangata.
# sentyabrskiy does not exist in OpenWeatherMap.
# Request 84 sent for san martin.
# Response code 200 received for san martin.
# Request 85 sent for bambous virieux.
# Response code 200 received for bambous virieux.
# Request 86 sent for ryotsu.
# Response code 200 received for ryotsu.
# Request 87 sent for deer lake.
# Response code 200 received for deer lake.
# Request 88 sent for nantucket.
# Response code 200 received for nantucket.
# Request 89 sent for tuktoyaktuk.
# Response code 200 received for tuktoyaktuk.
# Request 90 sent for corn island.
# Response code 200 received for corn island.
# Request 91 sent for lufkin.
# Response code 200 received for lufkin.
# Request 92 sent for lehigh acres.
# Response code 200 received for lehigh acres.
# Request 93 sent for bilibino.
# Response code 200 received for bilibino.
# Request 94 sent for leningradskiy.
# Response code 200 received for leningradskiy.
# Request 95 sent for cravo norte.
# Response code 200 received for cravo norte.
# Request 96 sent for teya.
# Response code 200 received for teya.
# Request 97 sent for sabha.
# Response code 200 received for sabha.
# Request 98 sent for high level.
# Response code 200 received for high level.
# Request 99 sent for waingapu.
# Response code 200 received for waingapu.
# Request 100 sent for amurzet.
# Response code 200 received for amurzet.
# Request 101 sent for srednekolymsk.
# Response code 200 received for srednekolymsk.
# Request 102 sent for tucumcari.
# Response code 200 received for tucumcari.
# Request 103 sent for plettenberg bay.
# Response code 200 received for plettenberg bay.
# Request 104 sent for dongzhen.
# Response code 200 received for dongzhen.
# Request 105 sent for sipe sipe.
# Response code 200 received for sipe sipe.
# Request 106 sent for ilulissat.
# Response code 200 received for ilulissat.
# Request 107 sent for cape town.
# Response code 200 received for cape town.
# Request 108 sent for neya.
# Response code 200 received for neya.
# Request 109 sent for moranbah.
# Response code 200 received for moranbah.
# Request 110 sent for zdvinsk.
# Response code 200 received for zdvinsk.
# bur gabo does not exist in OpenWeatherMap.
# Request 112 sent for la ronge.
# Response code 200 received for la ronge.
# Request 113 sent for yerofey pavlovich.
# Response code 200 received for yerofey pavlovich.
# Request 114 sent for port lincoln.
# Response code 200 received for port lincoln.
# Request 115 sent for key largo.
# Response code 200 received for key largo.
# Request 116 sent for chulumani.
# Response code 200 received for chulumani.
# Request 117 sent for araguaina.
# Response code 200 received for araguaina.
# Request 118 sent for sinnamary.
# Response code 200 received for sinnamary.
# armacao dos buzios does not exist in OpenWeatherMap.
# Request 120 sent for hasaki.
# Response code 200 received for hasaki.
# Request 121 sent for pevek.
# Response code 200 received for pevek.
# Request 122 sent for saint anthony.
# Response code 200 received for saint anthony.
# katsiveli does not exist in OpenWeatherMap.
# Request 124 sent for kodiak.
# Response code 200 received for kodiak.
# Request 125 sent for punta alta.
# Response code 200 received for punta alta.
# Request 126 sent for furano.
# Response code 200 received for furano.
# Request 127 sent for east london.
# Response code 200 received for east london.
# Request 128 sent for deputatskiy.
# Response code 200 received for deputatskiy.
# Request 129 sent for marzuq.
# Response code 200 received for marzuq.
# Request 130 sent for ewa beach.
# Response code 200 received for ewa beach.
# Request 131 sent for abu samrah.
# Response code 200 received for abu samrah.
# Request 132 sent for kotido.
# Response code 200 received for kotido.
# Request 133 sent for katima mulilo.
# Response code 200 received for katima mulilo.
# Request 134 sent for capitan bado.
# Response code 200 received for capitan bado.
# Request 135 sent for vardo.
# Response code 200 received for vardo.
# Request 136 sent for souillac.
# Response code 200 received for souillac.
# Request 137 sent for kharhial.
# Response code 200 received for kharhial.
# Request 138 sent for coihaique.
# Response code 200 received for coihaique.
# Request 139 sent for sao jose da coroa grande.
# Response code 200 received for sao jose da coroa grande.
# Request 140 sent for tessalit.
# Response code 200 received for tessalit.
# Request 141 sent for hermanus.
# Response code 200 received for hermanus.
# Request 142 sent for kampot.
# Response code 200 received for kampot.
# Request 143 sent for bathsheba.
# Response code 200 received for bathsheba.
# Request 144 sent for ribeira grande.
# Response code 200 received for ribeira grande.
# Request 145 sent for aklavik.
# Response code 200 received for aklavik.
# Request 146 sent for saldanha.
# Response code 200 received for saldanha.
# Request 147 sent for longyearbyen.
# Response code 200 received for longyearbyen.
# Request 148 sent for dingle.
# Response code 200 received for dingle.
# Request 149 sent for bor.
# Response code 200 received for bor.
# Request 150 sent for thompson.
# Response code 200 received for thompson.
# Request 151 sent for payerne.
# Response code 200 received for payerne.
# attawapiskat does not exist in OpenWeatherMap.
# Request 153 sent for jacareacanga.
# Response code 200 received for jacareacanga.
# meyungs does not exist in OpenWeatherMap.
# Request 155 sent for patiya.
# Response code 200 received for patiya.
# Request 156 sent for ndele.
# Response code 200 received for ndele.
# Request 157 sent for dikson.
# Response code 200 received for dikson.
# Request 158 sent for muisne.
# Response code 200 received for muisne.
# Request 159 sent for mgachi.
# Response code 200 received for mgachi.
# Request 160 sent for erenhot.
# Response code 200 received for erenhot.
# Request 161 sent for qaanaaq.
# Response code 200 received for qaanaaq.
# Request 162 sent for mount isa.
# Response code 200 received for mount isa.
# Request 163 sent for sarangani.
# Response code 200 received for sarangani.
# Request 164 sent for alice springs.
# Response code 200 received for alice springs.
# Request 165 sent for vaini.
# Response code 200 received for vaini.
# Request 166 sent for kieta.
# Response code 200 received for kieta.
# Request 167 sent for ponta do sol.
# Response code 200 received for ponta do sol.
# asayita does not exist in OpenWeatherMap.
# Request 169 sent for zarubino.
# Response code 200 received for zarubino.
# Request 170 sent for svetlogorsk.
# Response code 200 received for svetlogorsk.
# Request 171 sent for seoul.
# Response code 200 received for seoul.
# Request 172 sent for hongjiang.
# Response code 200 received for hongjiang.
# Request 173 sent for ancud.
# Response code 200 received for ancud.
# Request 174 sent for mar del plata.
# Response code 200 received for mar del plata.
# Request 175 sent for tuatapere.
# Response code 200 received for tuatapere.
# Request 176 sent for port augusta.
# Response code 200 received for port augusta.
# Request 177 sent for mount pleasant.
# Response code 200 received for mount pleasant.
# Request 178 sent for prince rupert.
# Response code 200 received for prince rupert.
# Request 179 sent for gamba.
# Response code 200 received for gamba.
# Request 180 sent for makakilo city.
# Response code 200 received for makakilo city.
# Request 181 sent for road town.
# Response code 200 received for road town.
# Request 182 sent for hirara.
# Response code 200 received for hirara.
# Request 183 sent for port hardy.
# Response code 200 received for port hardy.
# Request 184 sent for poum.
# Response code 200 received for poum.
# Request 185 sent for qurayyat.
# Response code 200 received for qurayyat.
# Request 186 sent for santa maria.
# Response code 200 received for santa maria.
# Request 187 sent for yeppoon.
# Response code 200 received for yeppoon.
# Request 188 sent for kaeo.
# Response code 200 received for kaeo.
# Request 189 sent for thaton.
# Response code 200 received for thaton.
# Request 190 sent for vila.
# Response code 200 received for vila.
# Request 191 sent for berlevag.
# Response code 200 received for berlevag.
# Request 192 sent for karratha.
# Response code 200 received for karratha.
# Request 193 sent for vostok.
# Response code 200 received for vostok.
# Request 194 sent for saint george.
# Response code 200 received for saint george.
# Request 195 sent for rongcheng.
# Response code 200 received for rongcheng.
# Request 196 sent for vanimo.
# Response code 200 received for vanimo.
# Request 197 sent for kilindoni.
# Response code 200 received for kilindoni.
# Request 198 sent for pacific grove.
# Response code 200 received for pacific grove.
# Request 199 sent for roseburg.
# Response code 200 received for roseburg.
# Request 200 sent for teeli.
# Response code 200 received for teeli.
# Request 201 sent for non sang.
# Response code 200 received for non sang.
# Request 202 sent for barrow.
# Response code 200 received for barrow.
# Request 203 sent for vestmannaeyjar.
# Response code 200 received for vestmannaeyjar.
# Request 204 sent for fort saint james.
# Response code 200 received for fort saint james.
# Request 205 sent for samokov.
# Response code 200 received for samokov.
# Request 206 sent for samana.
# Response code 200 received for samana.
# Request 207 sent for hailin.
# Response code 200 received for hailin.
# Request 208 sent for kupang.
# Response code 200 received for kupang.
# ziyamet does not exist in OpenWeatherMap.
# Request 210 sent for nhulunbuy.
# Response code 200 received for nhulunbuy.
# Request 211 sent for nikolskoye.
# Response code 200 received for nikolskoye.
# Request 212 sent for beringovskiy.
# Response code 200 received for beringovskiy.
# Request 213 sent for delvada.
# Response code 200 received for delvada.
# Request 214 sent for mbeya.
# Response code 200 received for mbeya.
# Request 215 sent for west wendover.
# Response code 200 received for west wendover.
# Request 216 sent for chokwe.
# Response code 200 received for chokwe.
# Request 217 sent for geraldton.
# Response code 200 received for geraldton.
# Request 218 sent for hambantota.
# Response code 200 received for hambantota.
# Request 219 sent for lokosovo.
# Response code 200 received for lokosovo.
# Request 220 sent for brigantine.
# Response code 200 received for brigantine.
# Request 221 sent for caravelas.
# Response code 200 received for caravelas.
# Request 222 sent for ust-barguzin.
# Response code 200 received for ust-barguzin.
# Request 223 sent for xichang.
# Response code 200 received for xichang.
# Request 224 sent for severo-kurilsk.
# Response code 200 received for severo-kurilsk.
# Request 225 sent for nabire.
# Response code 200 received for nabire.
# Request 226 sent for esperance.
# Response code 200 received for esperance.
# Request 227 sent for sitka.
# Response code 200 received for sitka.
# Request 228 sent for cap malheureux.
# Response code 200 received for cap malheureux.
# Request 229 sent for kahului.
# Response code 200 received for kahului.
# Request 230 sent for terrace.
# Response code 200 received for terrace.
# Request 231 sent for zhangjiakou.
# Response code 200 received for zhangjiakou.
# Request 232 sent for ayan.
# Response code 200 received for ayan.
# Request 233 sent for atlantic beach.
# Response code 200 received for atlantic beach.
# Request 234 sent for klaksvik.
# Response code 200 received for klaksvik.
# Request 235 sent for lakes entrance.
# Response code 200 received for lakes entrance.
# Request 236 sent for chuy.
# Response code 200 received for chuy.
# halalo does not exist in OpenWeatherMap.
# Request 238 sent for buta.
# Response code 200 received for buta.
# Request 239 sent for tiksi.
# Response code 200 received for tiksi.
# Request 240 sent for hibbing.
# Response code 200 received for hibbing.
# Request 241 sent for ambilobe.
# Response code 200 received for ambilobe.
# Request 242 sent for melendugno.
# Response code 200 received for melendugno.
# Request 243 sent for saint-philippe.
# Response code 200 received for saint-philippe.
# Request 244 sent for sao filipe.
# Response code 200 received for sao filipe.
# Request 245 sent for bara.
# Response code 200 received for bara.
# Request 246 sent for kruisfontein.
# Response code 200 received for kruisfontein.
# Request 247 sent for hwange.
# Response code 200 received for hwange.
# Request 248 sent for troitskoye.
# Response code 200 received for troitskoye.
# Request 249 sent for kirakira.
# Response code 200 received for kirakira.
# Request 250 sent for cartagena.
# Response code 200 received for cartagena.
# Request 251 sent for cherskiy.
# Response code 200 received for cherskiy.
# Request 252 sent for pisco.
# Response code 200 received for pisco.
# Request 253 sent for sribne.
# Response code 200 received for sribne.
# Request 254 sent for yonezawa.
# Response code 200 received for yonezawa.
# Request 255 sent for okhotsk.
# Response code 200 received for okhotsk.
# makung does not exist in OpenWeatherMap.
# Request 257 sent for saint-louis.
# Response code 200 received for saint-louis.
# Request 258 sent for kamenka.
# Response code 200 received for kamenka.
# Request 259 sent for port arthur.
# Response code 200 received for port arthur.
# Request 260 sent for garowe.
# Response code 200 received for garowe.
# Request 261 sent for mananara.
# Response code 200 received for mananara.
# Request 262 sent for kropotkin.
# Response code 200 received for kropotkin.
# Request 263 sent for khatanga.
# Response code 200 received for khatanga.
# Request 264 sent for puerto ayora.
# Response code 200 received for puerto ayora.
# Request 265 sent for chipinge.
# Response code 200 received for chipinge.
# Request 266 sent for port macquarie.
# Response code 200 received for port macquarie.
# Request 267 sent for cayenne.
# Response code 200 received for cayenne.
# Request 268 sent for peniche.
# Response code 200 received for peniche.
# Request 269 sent for hilo.
# Response code 200 received for hilo.
# Request 270 sent for cabo san lucas.
# Response code 200 received for cabo san lucas.
# Request 271 sent for maine-soroa.
# Response code 200 received for maine-soroa.
# Request 272 sent for maningrida.
# Response code 200 received for maningrida.
# Request 273 sent for neryungri.
# Response code 200 received for neryungri.
# Request 274 sent for bowen.
# Response code 200 received for bowen.
# Request 275 sent for samarai.
# Response code 200 received for samarai.
# Request 276 sent for tasiilaq.
# Response code 200 received for tasiilaq.
# Request 277 sent for pimentel.
# Response code 200 received for pimentel.
# Request 278 sent for bubaque.
# Response code 200 received for bubaque.
# Request 279 sent for siddapur.
# Response code 200 received for siddapur.
# Request 280 sent for gobabis.
# Response code 200 received for gobabis.
# Request 281 sent for college.
# Response code 200 received for college.
# Request 282 sent for zhenlai.
# Response code 200 received for zhenlai.
# Request 283 sent for luderitz.
# Response code 200 received for luderitz.
# Request 284 sent for xai-xai.
# Response code 200 received for xai-xai.
# Request 285 sent for faanui.
# Response code 200 received for faanui.
# Request 286 sent for bang saphan.
# Response code 200 received for bang saphan.
# Request 287 sent for remontnoye.
# Response code 200 received for remontnoye.
# mys shmidta does not exist in OpenWeatherMap.
# Request 289 sent for birao.
# Response code 200 received for birao.
# warqla does not exist in OpenWeatherMap.
# Request 291 sent for heishan.
# Response code 200 received for heishan.
# Request 292 sent for codrington.
# Response code 200 received for codrington.
# Request 293 sent for rio grande.
# Response code 200 received for rio grande.
# urdzhar does not exist in OpenWeatherMap.
# vaitupu does not exist in OpenWeatherMap.
# Request 296 sent for kaya.
# Response code 200 received for kaya.
# qabis does not exist in OpenWeatherMap.
# Request 298 sent for ajdabiya.
# Response code 200 received for ajdabiya.
# Request 299 sent for aswan.
# Response code 200 received for aswan.
# Request 300 sent for portland.
# Response code 200 received for portland.
# Request 301 sent for bure.
# Response code 200 received for bure.
# Request 302 sent for salalah.
# Response code 200 received for salalah.
# Request 303 sent for hamilton.
# Response code 200 received for hamilton.
# grand river south east does not exist in OpenWeatherMap.
# Request 305 sent for clearwater.
# Response code 200 received for clearwater.
# Request 306 sent for richards bay.
# Response code 200 received for richards bay.
# Request 307 sent for norman wells.
# Response code 200 received for norman wells.
# Request 308 sent for perth.
# Response code 200 received for perth.
# Request 309 sent for karakol.
# Response code 200 received for karakol.
# Request 310 sent for shimoda.
# Response code 200 received for shimoda.
# Request 311 sent for iwanai.
# Response code 200 received for iwanai.
# marcona does not exist in OpenWeatherMap.
# Request 313 sent for bonthe.
# Response code 200 received for bonthe.
# Request 314 sent for flinders.
# Response code 200 received for flinders.
# Request 315 sent for arraial do cabo.
# Response code 200 received for arraial do cabo.
# Request 316 sent for kakching.
# Response code 200 received for kakching.
# mrirt does not exist in OpenWeatherMap.
# Request 318 sent for mwinilunga.
# Response code 200 received for mwinilunga.
# Request 319 sent for bandraboua.
# Response code 200 received for bandraboua.
# Request 320 sent for mayo.
# Response code 200 received for mayo.
# Request 321 sent for oranjemund.
# Response code 200 received for oranjemund.
# Request 322 sent for ordynskoye.
# Response code 200 received for ordynskoye.
# Request 323 sent for weyburn.
# Response code 200 received for weyburn.
# Request 324 sent for boa vista.
# Response code 200 received for boa vista.
# Request 325 sent for lorengau.
# Response code 200 received for lorengau.
# Request 326 sent for broome.
# Response code 200 received for broome.
# Request 327 sent for ariquemes.
# Response code 200 received for ariquemes.
# Request 328 sent for amapa.
# Response code 200 received for amapa.
# angelholm does not exist in OpenWeatherMap.
# Request 330 sent for pietersburg.
# Response code 200 received for pietersburg.
# Request 331 sent for chapais.
# Response code 200 received for chapais.
# saleaula does not exist in OpenWeatherMap.
# Request 333 sent for nata.
# Response code 200 received for nata.
# Request 334 sent for waipawa.
# Response code 200 received for waipawa.
# Request 335 sent for altay.
# Response code 200 received for altay.
# Request 336 sent for havre-saint-pierre.
# Response code 200 received for havre-saint-pierre.
# Request 337 sent for callaway.
# Response code 200 received for callaway.
# dujuma does not exist in OpenWeatherMap.
# Request 339 sent for lavrentiya.
# Response code 200 received for lavrentiya.
# Request 340 sent for cheremshan.
# Response code 200 received for cheremshan.
# Request 341 sent for trelleborg.
# Response code 200 received for trelleborg.
# handwara does not exist in OpenWeatherMap.
# Request 343 sent for porto novo.
# Response code 200 received for porto novo.
# Request 344 sent for sampit.
# Response code 200 received for sampit.
# Request 345 sent for soe.
# Response code 200 received for soe.
# Request 346 sent for krasnohrad.
# Response code 200 received for krasnohrad.
# Request 347 sent for boden.
# Response code 200 received for boden.
# Request 348 sent for lazarev.
# Response code 200 received for lazarev.
# Request 349 sent for libertador general san martin.
# Response code 200 received for libertador general san martin.
# mentok does not exist in OpenWeatherMap.
# Request 351 sent for cabedelo.
# Response code 200 received for cabedelo.
# Request 352 sent for gorin.
# Response code 200 received for gorin.
# Request 353 sent for dangriga.
# Response code 200 received for dangriga.
# Request 354 sent for epping.
# Response code 200 received for epping.
# jabiru does not exist in OpenWeatherMap.
# Request 356 sent for bow island.
# Response code 200 received for bow island.
# Request 357 sent for virginia beach.
# Response code 200 received for virginia beach.
# Request 358 sent for alofi.
# Response code 200 received for alofi.
# Request 359 sent for itoman.
# Response code 200 received for itoman.
# Request 360 sent for pangai.
# Response code 200 received for pangai.
# Request 361 sent for godfrey.
# Response code 200 received for godfrey.
# wahran does not exist in OpenWeatherMap.
# Request 363 sent for malindi.
# Response code 200 received for malindi.
# Request 364 sent for barranca.
# Response code 200 received for barranca.
# Request 365 sent for chenzhou.
# Response code 200 received for chenzhou.
# Request 366 sent for kletskaya.
# Response code 200 received for kletskaya.
# Request 367 sent for san patricio.
# Response code 200 received for san patricio.
# Request 368 sent for zhicheng.
# Response code 200 received for zhicheng.
# Request 369 sent for sitio novo do tocantins.
# Response code 200 received for sitio novo do tocantins.
# Request 370 sent for muros.
# Response code 200 received for muros.
# xghajra does not exist in OpenWeatherMap.
# Request 372 sent for thinadhoo.
# Response code 200 received for thinadhoo.
# Request 373 sent for chingirlau.
# Response code 200 received for chingirlau.
# Request 374 sent for harbour breton.
# Response code 200 received for harbour breton.
# Request 375 sent for provideniya.
# Response code 200 received for provideniya.
# Request 376 sent for lodwar.
# Response code 200 received for lodwar.
# Request 377 sent for carutapera.
# Response code 200 received for carutapera.
# Request 378 sent for bengkulu.
# Response code 200 received for bengkulu.
# Request 379 sent for pindi gheb.
# Response code 200 received for pindi gheb.
# Request 380 sent for komsomolskiy.
# Response code 200 received for komsomolskiy.
# Request 381 sent for ortigueira.
# Response code 200 received for ortigueira.
# Request 382 sent for malakal.
# Response code 200 received for malakal.
# Request 383 sent for tura.
# Response code 200 received for tura.
# Request 384 sent for faya.
# Response code 200 received for faya.
# Request 385 sent for gravdal.
# Response code 200 received for gravdal.
# Request 386 sent for ketchikan.
# Response code 200 received for ketchikan.
# Request 387 sent for kargil.
# Response code 200 received for kargil.
# Request 388 sent for polyarnyy.
# Response code 200 received for polyarnyy.
# Request 389 sent for nouadhibou.
# Response code 200 received for nouadhibou.
# Request 390 sent for novoseleznevo.
# Response code 200 received for novoseleznevo.
# Request 391 sent for shieli.
# Response code 200 received for shieli.
# Request 392 sent for beberibe.
# Response code 200 received for beberibe.
# Request 393 sent for roald.
# Response code 200 received for roald.
# tumannyy does not exist in OpenWeatherMap.
# Request 395 sent for shumskiy.
# Response code 200 received for shumskiy.
# Request 396 sent for nuuk.
# Response code 200 received for nuuk.
# Request 397 sent for the valley.
# Response code 200 received for the valley.
# Request 398 sent for estacion coahuila.
# Response code 200 received for estacion coahuila.
# Request 399 sent for katsuura.
# Response code 200 received for katsuura.
# Request 400 sent for conde.
# Response code 200 received for conde.
# Request 401 sent for revda.
# Response code 200 received for revda.
# Request 402 sent for port said.
# Response code 200 received for port said.
# Request 403 sent for bohuslav.
# Response code 200 received for bohuslav.
# Request 404 sent for fernandina beach.
# Response code 200 received for fernandina beach.
# Request 405 sent for ust-omchug.
# Response code 200 received for ust-omchug.
# Request 406 sent for vermillion.
# Response code 200 received for vermillion.
# macaboboni does not exist in OpenWeatherMap.
# Request 408 sent for tilichiki.
# Response code 200 received for tilichiki.
# Request 409 sent for khuzhir.
# Response code 200 received for khuzhir.
# Request 410 sent for paullo.
# Response code 200 received for paullo.
# Request 411 sent for harbin.
# Response code 200 received for harbin.
# Request 412 sent for sosnovka.
# Response code 200 received for sosnovka.
# Request 413 sent for ternate.
# Response code 200 received for ternate.
# Request 414 sent for maroua.
# Response code 200 received for maroua.
# Request 415 sent for korla.
# Response code 200 received for korla.
# Request 416 sent for husavik.
# Response code 200 received for husavik.
# Request 417 sent for tautira.
# Response code 200 received for tautira.
# Request 418 sent for soyo.
# Response code 200 received for soyo.
# Request 419 sent for manzanillo.
# Response code 200 received for manzanillo.
# Request 420 sent for verkhnyaya inta.
# Response code 200 received for verkhnyaya inta.
# Request 421 sent for asau.
# Response code 200 received for asau.
# Request 422 sent for abasolo.
# Response code 200 received for abasolo.
# Request 423 sent for vao.
# Response code 200 received for vao.
# Request 424 sent for shache.
# Response code 200 received for shache.
# Request 425 sent for honiara.
# Response code 200 received for honiara.
# tarudant does not exist in OpenWeatherMap.
# Request 427 sent for metro.
# Response code 200 received for metro.
# palabuhanratu does not exist in OpenWeatherMap.
# Request 429 sent for touros.
# Response code 200 received for touros.
# bolungarvik does not exist in OpenWeatherMap.
# Request 431 sent for guilin.
# Response code 200 received for guilin.
# Request 432 sent for greenwood.
# Response code 200 received for greenwood.
# Request 433 sent for talnakh.
# Response code 200 received for talnakh.
# Request 434 sent for troitsk.
# Response code 200 received for troitsk.
# Request 435 sent for isangel.
# Response code 200 received for isangel.
# Request 436 sent for bridlington.
# Response code 200 received for bridlington.
# Request 437 sent for tacuati.
# Response code 200 received for tacuati.
# Request 438 sent for raudeberg.
# Response code 200 received for raudeberg.
# Request 439 sent for tokur.
# Response code 200 received for tokur.
# Request 440 sent for orodara.
# Response code 200 received for orodara.
# Request 441 sent for natchez.
# Response code 200 received for natchez.
# chikoy does not exist in OpenWeatherMap.
# Request 443 sent for ahipara.
# Response code 200 received for ahipara.
# Request 444 sent for puerto leguizamo.
# Response code 200 received for puerto leguizamo.
# Request 445 sent for bereda.
# Response code 200 received for bereda.
# Request 446 sent for rome.
# Response code 200 received for rome.
# Request 447 sent for tromso.
# Response code 200 received for tromso.
# Request 448 sent for miyako.
# Response code 200 received for miyako.
# Request 449 sent for bolgar.
# Response code 200 received for bolgar.
# Request 450 sent for tabou.
# Response code 200 received for tabou.
# Request 451 sent for northam.
# Response code 200 received for northam.
# Request 452 sent for te anau.
# Response code 200 received for te anau.
# Request 453 sent for san buenaventura.
# Response code 200 received for san buenaventura.
# Request 454 sent for kudahuvadhoo.
# Response code 200 received for kudahuvadhoo.
# Request 455 sent for meulaboh.
# Response code 200 received for meulaboh.
# Request 456 sent for zhigansk.
# Response code 200 received for zhigansk.
# Request 457 sent for conceicao do araguaia.
# Response code 200 received for conceicao do araguaia.
# Request 458 sent for gombe.
# Response code 200 received for gombe.
# Request 459 sent for filadelfia.
# Response code 200 received for filadelfia.
# Request 460 sent for bayangol.
# Response code 200 received for bayangol.
# Request 461 sent for bougouni.
# Response code 200 received for bougouni.
# Request 462 sent for rantepao.
# Response code 200 received for rantepao.
# Request 463 sent for buchanan.
# Response code 200 received for buchanan.
# Request 464 sent for nalut.
# Response code 200 received for nalut.
# Request 465 sent for manta.
# Response code 200 received for manta.
# Request 466 sent for hendaye.
# Response code 200 received for hendaye.
# Request 467 sent for narsaq.
# Response code 200 received for narsaq.
# Request 468 sent for lagoa.
# Response code 200 received for lagoa.
# Request 469 sent for banda aceh.
# Response code 200 received for banda aceh.
# Request 470 sent for lata.
# Response code 200 received for lata.
# Request 471 sent for truth or consequences.
# Response code 200 received for truth or consequences.
# Request 472 sent for novoagansk.
# Response code 200 received for novoagansk.
# Request 473 sent for sur.
# Response code 200 received for sur.
# Request 474 sent for moundou.
# Response code 200 received for moundou.
# falealupo does not exist in OpenWeatherMap.
# Request 476 sent for emerald.
# Response code 200 received for emerald.
# inderborskiy does not exist in OpenWeatherMap.
# Request 478 sent for tianpeng.
# Response code 200 received for tianpeng.
# Request 479 sent for jieshi.
# Response code 200 received for jieshi.
# Request 480 sent for clyde river.
# Response code 200 received for clyde river.
# Request 481 sent for bonavista.
# Response code 200 received for bonavista.
# Request 482 sent for aksu.
# Response code 200 received for aksu.
# Request 483 sent for cognac.
# Response code 200 received for cognac.
# Request 484 sent for constitucion.
# Response code 200 received for constitucion.
# Request 485 sent for liverpool.
# Response code 200 received for liverpool.
# Request 486 sent for khandagayty.
# Response code 200 received for khandagayty.
# Request 487 sent for boende.
# Response code 200 received for boende.
# Request 488 sent for fort-shevchenko.
# Response code 200 received for fort-shevchenko.
# Request 489 sent for faranah.
# Response code 200 received for faranah.
# Request 490 sent for hobyo.
# Response code 200 received for hobyo.
# Request 491 sent for mackay.
# Response code 200 received for mackay.
# Request 492 sent for tiarei.
# Response code 200 received for tiarei.
# Request 493 sent for kolondieba.
# Response code 200 received for kolondieba.
# Request 494 sent for uyuni.
# Response code 200 received for uyuni.
# Request 495 sent for mattru.
# Response code 200 received for mattru.
# Request 496 sent for abnub.
# Response code 200 received for abnub.
# Request 497 sent for opuwo.
# Response code 200 received for opuwo.
# Request 498 sent for rapid valley.
# Response code 200 received for rapid valley.
# ijaki does not exist in OpenWeatherMap.
# Request 500 sent for doctor mora.
# Response code 200 received for doctor mora.
# Request 501 sent for areosa.
# Response code 200 received for areosa.
# Request 502 sent for pervomayskiy.
# Response code 200 received for pervomayskiy.
# Request 503 sent for nishihara.
# Response code 200 received for nishihara.
# Request 504 sent for jadu.
# Response code 200 received for jadu.
# Request 505 sent for nanortalik.
# Response code 200 received for nanortalik.
# Request 506 sent for yar-sale.
# Response code 200 received for yar-sale.
# Request 507 sent for korcula.
# Response code 200 received for korcula.
# Request 508 sent for port blair.
# Response code 200 received for port blair.
# Request 509 sent for mae sai.
# Response code 200 received for mae sai.
# Request 510 sent for ratnagiri.
# Response code 200 received for ratnagiri.
# Request 511 sent for salto.
# Response code 200 received for salto.
# Request 512 sent for flin flon.
# Response code 200 received for flin flon.
# Request 513 sent for pouebo.
# Response code 200 received for pouebo.
# Request 514 sent for victoria point.
# Response code 200 received for victoria point.
# Request 515 sent for marhaura.
# Response code 200 received for marhaura.
# Request 516 sent for waterloo.
# Response code 200 received for waterloo.
# Request 517 sent for kamaishi.
# Response code 200 received for kamaishi.
# Request 518 sent for buala.
# Response code 200 received for buala.
# Request 519 sent for praia da vitoria.
# Response code 200 received for praia da vitoria.
# Request 520 sent for matay.
# Response code 200 received for matay.
# Request 521 sent for isabela.
# Response code 200 received for isabela.
# yialos does not exist in OpenWeatherMap.
# Request 523 sent for rocha.
# Response code 200 received for rocha.
# Request 524 sent for rio bravo.
# Response code 200 received for rio bravo.
# Request 525 sent for fort nelson.
# Response code 200 received for fort nelson.
# tabiauea does not exist in OpenWeatherMap.
# Request 527 sent for pilar.
# Response code 200 received for pilar.
# Request 528 sent for nome.
# Response code 200 received for nome.
# haibowan does not exist in OpenWeatherMap.
# Request 530 sent for wajima.
# Response code 200 received for wajima.
# Request 531 sent for mago.
# Response code 200 received for mago.
# Request 532 sent for bandarbeyla.
# Response code 200 received for bandarbeyla.
# Request 533 sent for konya.
# Response code 200 received for konya.
# Request 534 sent for aykhal.
# Response code 200 received for aykhal.
# Request 535 sent for atambua.
# Response code 200 received for atambua.
# Request 536 sent for arlit.
# Response code 200 received for arlit.
# stoyba does not exist in OpenWeatherMap.
# Request 538 sent for whitehorse.
# Response code 200 received for whitehorse.
# Request 539 sent for yining.
# Response code 200 received for yining.
# Request 540 sent for saint-pierre.
# Response code 200 received for saint-pierre.
# Request 541 sent for kysyl-syr.
# Response code 200 received for kysyl-syr.
# Request 542 sent for auki.
# Response code 200 received for auki.
# Request 543 sent for birjand.
# Response code 200 received for birjand.
# Request 544 sent for valdemarpils.
# Response code 200 received for valdemarpils.
# Request 545 sent for avera.
# Response code 200 received for avera.
# barbar does not exist in OpenWeatherMap.
# Request 547 sent for ucluelet.
# Response code 200 received for ucluelet.
# Request 548 sent for lagunillas.
# Response code 200 received for lagunillas.
# Request 549 sent for beloha.
# Response code 200 received for beloha.
# Request 550 sent for khilok.
# Response code 200 received for khilok.
# Request 551 sent for henties bay.
# Response code 200 received for henties bay.
# Request 552 sent for diamantino.
# Response code 200 received for diamantino.
# Request 553 sent for puerto escondido.
# Response code 200 received for puerto escondido.
# Request 554 sent for mirwah.
# Response code 200 received for mirwah.
# Request 555 sent for kletnya.
# Response code 200 received for kletnya.
# sorvag does not exist in OpenWeatherMap.
# Request 557 sent for lundazi.
# Response code 200 received for lundazi.
# Request 558 sent for ondangwa.
# Response code 200 received for ondangwa.
# Request 559 sent for chara.
# Response code 200 received for chara.
# Request 560 sent for el alto.
# Response code 200 received for el alto.
# Request 561 sent for fare.
# Response code 200 received for fare.
# Request 562 sent for vestmanna.
# Response code 200 received for vestmanna.
# Request 563 sent for cotonou.
# Response code 200 received for cotonou.
# Request 564 sent for unai.
# Response code 200 received for unai.
# Request 565 sent for sakakah.
# Response code 200 received for sakakah.
# Request 566 sent for steinbach.
# Response code 200 received for steinbach.
# Request 567 sent for manali.
# Response code 200 received for manali.
# Request 568 sent for lasa.
# Response code 200 received for lasa.
# Request 569 sent for sao joao da barra.
# Response code 200 received for sao joao da barra.
# Request 570 sent for tevaitoa.
# Response code 200 received for tevaitoa.
# Request 571 sent for pangnirtung.
# Response code 200 received for pangnirtung.
# Request 572 sent for ulladulla.
# Response code 200 received for ulladulla.
# Request 573 sent for kachiry.
# Response code 200 received for kachiry.
# Request 574 sent for grand-santi.
# Response code 200 received for grand-santi.
# Request 575 sent for stolin.
# Response code 200 received for stolin.
# Request 576 sent for hvolsvollur.
# Response code 200 received for hvolsvollur.
# paradwip does not exist in OpenWeatherMap.
# Request 578 sent for grand gaube.
# Response code 200 received for grand gaube.
# Request 579 sent for gumla.
# Response code 200 received for gumla.
# Request 580 sent for ugoofaaru.
# Response code 200 received for ugoofaaru.
# Request 581 sent for iquitos.
# Response code 200 received for iquitos.
# Request 582 sent for adrar.
# Response code 200 received for adrar.
# Request 583 sent for suntar.
# Response code 200 received for suntar.
# Request 584 sent for tobolsk.
# Response code 200 received for tobolsk.
# Request 585 sent for kholodnyy.
# Response code 200 received for kholodnyy.
# Request 586 sent for ippy.
# Response code 200 received for ippy.
# karamay does not exist in OpenWeatherMap.
# Request 588 sent for takoradi.
# Response code 200 received for takoradi.
# Request 589 sent for wageningen.
# Response code 200 received for wageningen.
# Request 590 sent for san pedro carcha.
# Response code 200 received for san pedro carcha.
# Request 591 sent for denpasar.
# Response code 200 received for denpasar.
# Request 592 sent for okha.
# Response code 200 received for okha.
# Request 593 sent for airai.
# Response code 200 received for airai.
# Request 594 sent for otjimbingwe.
# Response code 200 received for otjimbingwe.
# Request 595 sent for atar.
# Response code 200 received for atar.
# Request 596 sent for tazovskiy.
# Response code 200 received for tazovskiy.
# hihifo does not exist in OpenWeatherMap.
# Request 598 sent for sinegorye.
# Response code 200 received for sinegorye.
# Request 599 sent for urumqi.
# Response code 200 received for urumqi.
# Request 600 sent for maceio.
# Response code 200 received for maceio.
# Request 601 sent for guatire.
# Response code 200 received for guatire.
# Request 602 sent for semikarakorsk.
# Response code 200 received for semikarakorsk.
# Request 603 sent for surab.
# Response code 200 received for surab.
# yithion does not exist in OpenWeatherMap.
# utiroa does not exist in OpenWeatherMap.
# Request 606 sent for ishii.
# Response code 200 received for ishii.
# Request 607 sent for oistins.
# Response code 200 received for oistins.
# Request 608 sent for gumrak.
# Response code 200 received for gumrak.
# Request 609 sent for saint-georges.
# Response code 200 received for saint-georges.
# Request 610 sent for kununurra.
# Response code 200 received for kununurra.
# Request 611 sent for lerwick.
# Response code 200 received for lerwick.
# Request 612 sent for santa cruz.
# Response code 200 received for santa cruz.
# nguiu does not exist in OpenWeatherMap.
# Request 614 sent for spokane.
# Response code 200 received for spokane.
# Request 615 sent for hay river.
# Response code 200 received for hay river.
# Request 616 sent for qixia.
# Response code 200 received for qixia.
# Request 617 sent for ola.
# Response code 200 received for ola.
# Request 618 sent for teguise.
# Response code 200 received for teguise.
# Request 619 sent for kurilsk.
# Response code 200 received for kurilsk.
# Request 620 sent for tygda.
# Response code 200 received for tygda.
# Request 621 sent for iquique.
# Response code 200 received for iquique.
# Request 622 sent for kasongo-lunda.
# Response code 200 received for kasongo-lunda.
# Request 623 sent for saint-joseph.
# Response code 200 received for saint-joseph.
# Request 624 sent for havoysund.
# Response code 200 received for havoysund.
# Request 625 sent for gander.
# Response code 200 received for gander.
# Request 626 sent for sim.
# Response code 200 received for sim.
# Request 627 sent for bestobe.
# Response code 200 received for bestobe.
# Request 628 sent for karsun.
# Response code 200 received for karsun.
# Request 629 sent for tukums.
# Response code 200 received for tukums.
# Request 630 sent for nouakchott.
# Response code 200 received for nouakchott.
# Request 631 sent for antofagasta.
# Response code 200 received for antofagasta.
# Request 632 sent for quang ngai.
# Response code 200 received for quang ngai.
# Request 633 sent for kodinsk.
# Response code 200 received for kodinsk.
# azimur does not exist in OpenWeatherMap.
# Request 635 sent for zyryanovsk.
# Response code 200 received for zyryanovsk.
# Request 636 sent for north bend.
# Response code 200 received for north bend.
# Request 637 sent for carmo do paranaiba.
# Response code 200 received for carmo do paranaiba.
# Request 638 sent for westlock.
# Response code 200 received for westlock.
# Request 639 sent for riyadh.
# Response code 200 received for riyadh.
# Request 640 sent for erzin.
# Response code 200 received for erzin.
# Request 641 sent for moerai.
# Response code 200 received for moerai.
# Request 642 sent for murdochville.
# Response code 200 received for murdochville.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather_dict ={"city": city1, "latitude": lat, "longitude": long, "Max Temp": max_temp,
                   "humidity": humid, "Feels Like": temp, "cloudiness": clouds, "wind speed": winds,
                   "country": country, "datetime": datetime}

# %%
city_weather = pd.DataFrame(city_weather_dict)
city_weather.head()
# Out:
#          city  latitude  longitude  Max Temp  humidity  Feels Like  \
# 0    Fatehpur   25.9333    80.8000     77.68        91       79.43
# 1   Jamestown   42.0970   -79.2353     74.84        68       74.95
# 2     Ushuaia  -54.8000   -68.3000     47.86        66       45.25
# 3      Castro  -24.7911   -50.0119     58.15        80       57.43
# 4  Chokurdakh   70.6333   147.9167     56.95        83       56.25
#
#    cloudiness  wind speed country    datetime
# 0          99        9.08      IN  1661110697
# 1          75        5.75      US  1661110697
# 2         100        5.75      AR  1661110698
# 3          97        4.90      BR  1661110699
# 4         100        3.74      RU  1661110699

# %%
# unix, UTC timestamp conversion from:
# https://www.codegrepper.com/code-examples/python/convert+unix+timestamp+to+datetime+python+pandas
city_weather["date"] = pd.to_datetime(city_weather["datetime"], unit="s").dt.tz_localize("US/Pacific")

city_weather.head()
# Out:
#          city  latitude  longitude  Max Temp  humidity  Feels Like  \
# 0    Fatehpur   25.9333    80.8000     77.68        91       79.43
# 1   Jamestown   42.0970   -79.2353     74.84        68       74.95
# 2     Ushuaia  -54.8000   -68.3000     47.86        66       45.25
# 3      Castro  -24.7911   -50.0119     58.15        80       57.43
# 4  Chokurdakh   70.6333   147.9167     56.95        83       56.25
#
#    cloudiness  wind speed country    datetime                      date
# 0          99        9.08      IN  1661110697 2022-08-21 19:38:17-07:00
# 1          75        5.75      US  1661110697 2022-08-21 19:38:17-07:00
# 2         100        5.75      AR  1661110698 2022-08-21 19:38:18-07:00
# 3          97        4.90      BR  1661110699 2022-08-21 19:38:19-07:00
# 4         100        3.74      RU  1661110699 2022-08-21 19:38:19-07:00

# %%
# found country converter to convert from ISO 2 letter country to country name at the following"
# https://pypi.org/project/country-converter/
# https://stackoverflow.com/questions/64051741/how-to-convert-country-code-to-name-with-country-converter-in-pandas
# https://notebook.community/konstantinstadler/country_converter/doc/country_converter_examples
converter = coco.CountryConverter()
city_weather["country name"] = converter.convert(city_weather["country"], src="ISO2", to="name_short")

# %%
city_weather.head()
# Out:
#          city  latitude  longitude  Max Temp  humidity  Feels Like  \
# 0    Fatehpur   25.9333    80.8000     77.68        91       79.43
# 1   Jamestown   42.0970   -79.2353     74.84        68       74.95
# 2     Ushuaia  -54.8000   -68.3000     47.86        66       45.25
# 3      Castro  -24.7911   -50.0119     58.15        80       57.43
# 4  Chokurdakh   70.6333   147.9167     56.95        83       56.25
#
#    cloudiness  wind speed country    datetime                      date  \
# 0          99        9.08      IN  1661110697 2022-08-21 19:38:17-07:00
# 1          75        5.75      US  1661110697 2022-08-21 19:38:17-07:00
# 2         100        5.75      AR  1661110698 2022-08-21 19:38:18-07:00
# 3          97        4.90      BR  1661110699 2022-08-21 19:38:19-07:00
# 4         100        3.74      RU  1661110699 2022-08-21 19:38:19-07:00
#
#     country name
# 0          India
# 1  United States
# 2      Argentina
# 3         Brazil
# 4         Russia

# %%
city_weather2 = city_weather[["city", "latitude", "longitude", "Max Temp", "humidity",
                             "Feels Like", "cloudiness", "wind speed", "country name",
                             "date"]] 
city_weather2.head()
# Out:
#          city  latitude  longitude  Max Temp  humidity  Feels Like  \
# 0    Fatehpur   25.9333    80.8000     77.68        91       79.43
# 1   Jamestown   42.0970   -79.2353     74.84        68       74.95
# 2     Ushuaia  -54.8000   -68.3000     47.86        66       45.25
# 3      Castro  -24.7911   -50.0119     58.15        80       57.43
# 4  Chokurdakh   70.6333   147.9167     56.95        83       56.25
#
#    cloudiness  wind speed   country name                      date
# 0          99        9.08          India 2022-08-21 19:38:17-07:00
# 1          75        5.75  United States 2022-08-21 19:38:17-07:00
# 2         100        5.75      Argentina 2022-08-21 19:38:18-07:00
# 3          97        4.90         Brazil 2022-08-21 19:38:19-07:00
# 4         100        3.74         Russia 2022-08-21 19:38:19-07:00

# %%
city_weather2.to_csv("vacation_output_data/cities.csv")
len(city_weather2)
# Out:
# 586

# %%
request_response_dict = {"city": city1, "request sent": print_request, "response received": print_response}
request_response = pd.DataFrame(request_response_dict)
request_response.head()
# Out:
#          city                    request sent  \
# 0    Fatehpur    Request 0 sent for fatehpur.
# 1   Jamestown   Request 1 sent for jamestown.
# 2     Ushuaia     Request 2 sent for ushuaia.
# 3      Castro      Request 4 sent for castro.
# 4  Chokurdakh  Request 5 sent for chokurdakh.
#
#                             response received
# 0    Response code 200 received for fatehpur.
# 1   Response code 200 received for jamestown.
# 2     Response code 200 received for ushuaia.
# 3      Response code 200 received for castro.
# 4  Response code 200 received for chokurdakh.

# %%
request_response.to_csv("vacation_output_data/request_response_log.csv", index=False)
len(request_response)
# Out:
# 586

# %%
city_dne_dict = {"city": city2, "response received": print_dne}
city_dne = pd.DataFrame(city_dne_dict)
city_dne.head()
# Out:
#                city                                  response received
# 0     belushya guba    belushya guba does not exist in OpenWeatherMap.
# 1  illoqqortoormiut  illoqqortoormiut does not exist in OpenWeather...
# 2         taolanaro        taolanaro does not exist in OpenWeatherMap.
# 3       nizhneyansk      nizhneyansk does not exist in OpenWeatherMap.
# 4         umzimvubu        umzimvubu does not exist in OpenWeatherMap.

# %%
city_dne.to_csv("vacation_output_data/response_error_log.csv", index=False)

len(city_dne)
# Out:
# 57

# %% [markdown]
# ## Narrow down the DataFrame to find your ideal weather condition. For example:
# - A max temperature lower than 80 degrees but higher than 70.
# - Wind speed less than 10 mph.
# - Zero cloudiness.
# - Drop any rows that don't satisfy all three conditions. You want to be sure the weather is ideal.
# ----
# - **Note:** Feel free to adjust your specifications, but make sure to limit the number of rows returned by your API requests to a reasonable number.
# - Try to reduce the results in your DataFrame to 10 or fewer cities.

# %%
# Using Feels Like temperature since it considers humidity and temperature together in a Heat Index.
# Running this .loc with Feels Like > 70 degrees and < 8 degrees.
# With latitude between -30 degrees South and 30 degrees North.  "Some place tropical."
# With cloudiness < 25% and winds less than 10  mph.
# Adjust humidity percent until get to 10 or less results.
ideal_feels = city_weather2.loc[(city_weather2["Feels Like"] > 70) & (city_weather2["Feels Like"] < 80), :]
#ideal_lat = ideal_feels.loc[(ideal_feels["latitude"] > -25) & (ideal_feels["latitude"] < 25), :]                             
ideal_clouds = ideal_feels.loc[(ideal_feels["cloudiness"] == 0), :]
ideal_winds = ideal_clouds.loc[(ideal_clouds["wind speed"] < 10), :]
#ideal_humidity = ideal_winds.loc[(ideal_winds["humidity"] < 70), :]
#ideal_feels
#len(ideal_feels) # 177
#ideal_lat
#len(ideal_lat) # 111
#ideal_clouds
#len(ideal_clouds) # 22
#ideal_winds
#len(ideal_winds) # 13
#ideal_humidity = ideal_feels.loc[(ideal_feels["humidity"] < 70), :]
#ideal_humidity
#ideal_lat = ideal_humidity.loc[(ideal_humidity["latitude"] > -30) & (ideal_feels["latitude"] < 30), :]
#ideal_clouds = ideal_lat.loc[(ideal_lat["cloudiness"] < 75), :]
#ideal_clouds
#len(ideal_lat) # 4
#ideal_winds
#len(ideal_winds) # 10
ideal = ideal_winds.reset_index(drop=True)
ideal
# Out:
#                             city  latitude  longitude  Max Temp  humidity  \
# 0                      Nantucket   41.2835   -70.0995     80.71        60
# 1                        Terrace   54.5163  -128.6035     76.91        43
# 2                        Hibbing   47.4272   -92.9377     76.57        38
# 3                Havre-St-Pierre   50.2334   -63.5986     77.36        61
# 4  Libertador General San Martín  -23.8064   -64.7876     75.97        15
# 5                     Vermillion   42.7794   -96.9292     79.81        38
# 6                        Tacuatí  -23.4500   -56.5833     77.50        49
# 7                           Jadu   31.9530    12.0261     73.49        55
# 8                        Korčula   42.9622    17.1369     77.09        67
# 9                         Wajima   37.4000   136.9000     75.70        79
#
#    Feels Like  cloudiness  wind speed   country name                      date
# 0       72.05           0        6.91  United States 2022-08-21 19:37:06-07:00
# 1       76.32           0        4.61         Canada 2022-08-21 19:39:04-07:00
# 2       73.44           0        6.91  United States 2022-08-21 19:40:22-07:00
# 3       77.67           0        4.61         Canada 2022-08-21 19:41:04-07:00
# 4       73.98           0        4.88      Argentina 2022-08-21 19:41:14-07:00
# 5       78.96           0        4.41  United States 2022-08-21 19:41:39-07:00
# 6       77.25           0        4.07       Paraguay 2022-08-21 19:41:54-07:00
# 7       73.13           0        8.55          Libya 2022-08-21 19:42:24-07:00
# 8       77.65           0        9.78        Croatia 2022-08-21 19:42:25-07:00
# 9       76.69           0        8.57          Japan 2022-08-21 19:42:34-07:00

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * You must take a screenshot of the heatmap that you create and include it in your submission
# * Google Maps
# ------
# * Use Google Places API to find the first hotel for each city located within 5,000 meters of your coordinates.
# * Plot the hotels on top of the humidity heatmap, with each pin containing the **Hotel Name**, **City**, and **Country**.
# * A heatmap is successfully created.
# * For max intensity in the heatmap, try setting it to the highest humidity found in the dataset.
# * Ten or less pins for all the cities in the DataFrame.
# * Pins are clickable to display City, Country and Hotel Name.
# * Placed on top of the heatmap.

# %% [markdown]
# ## Humidity Heatmap

# %%
# Use Activities 3 Airport Ratings for loops and radius
# Use Activities 3 airport_heatmap for heatmap
# Use Activites 3 Banking_Desert_HeatMap for heatmap markers

# %%
# Store latitude and longitude in locations
locations = ideal_winds[["latitude", "longitude"]]
len(locations)
# Out:
# 10

# %%
#places = [ideal_winds[["latitude", "longitude"]]]
#print(places)

# %%
# type(locations)  # DataFrame

# %%
humid = ideal_winds["humidity"]
#humid
#type(humid)
len(humid)
# Out:
# 10

# %%
# Customize the size of the map
figure_layout = {
    'width': '80%',
    'margin': '0 auto 0 auto',
    'padding': '1px',
    'border': '1px solid black'
}

# Plot Heatmap
fig = gmaps.figure(layout=figure_layout, map_type='SATELLITE',
                  zoom_level=2, center=(30.267, -97.743),
                  display_toolbar=False)

# I TURNED OFF display_toolbar IN ORDER TO DOWNLOAD A PNG OF THE HEATMAP.  I TURNED IT BACK ON BEFORE I FILED.

# Create heatmap layer
heatmap_layer = gmaps.heatmap_layer(locations, weights=humid,
                                dissipating=False, max_intensity=79,
                                point_radius=5, opacity = 1.0)

# Add layer
fig.add_layer(heatmap_layer)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='420px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### If I say lived in a cruddy climate, where it was windy and rainy all of the time, and I wanted to travel somewhere with ideal weather right now, I might define the location based on ideal weather conditions consisting of cloudless days, winds less than 10 mph, and the temperature is between 70 and 80 degrees Fahrenheit.  Someone wants to make my dream come true, but I can only choose from a list of 500 - 600 randomly selected cities anywhere in the world before I apply my weather conditions.  As it turns out, I only get to choose from the 10 results shown on the heatmap, and the list started with 586 cities!

# %% [markdown]
# ### This heatmap is based on humidity with the city in Japan having the highest intensity, and the city in Argentina having the lowest intensity.

# %% [markdown]
# ## Humidity Heatmap with Markers

# %%
# Store city and country name in location_name
location_name = ideal_winds[["city", "country name"]]
#type(location_name)
#print(location_name)

# %%
# From Activities 3 Google Places
# From Activities 3 NearestRestr
# From Activities 3 Airport_Ratings

# %%
# set up additional columns to hold results from requests
#places = locations[["latitude", "longitude"]]
#places.loc[index, "name"] = ""
#places.loc[index, "address"] = ""
#places.loc[index, "rating"] = ""
#places.head()

# %%
# geocoordinates
# use locations list
#target_search = "hotel"
#target_radius = 5000
#target_type = "lodging"
#target_ranking = "rankby"

#            # set up a parameters dictionary
#
#            #    "keyword": "hotel",
#            params = {
#                "radius": 1000,
#                "type": "lodging",
#                "key": gkey
#            }
#            #    "keyword": target_search,
#
#
#
#            # use iterrows to iterate through the locations DataFrame
#            for index, row in places.iterrows():
#                # get lat, lng from df
#                lat = row["latitude"]
#                lng = row["longitude"]
#
#                # change location each iteration while leaving original params in place
#                params["location"] = f"{lat},{lng}"
#
#                # Use the search term: "hotel" and our lat/lng
#                base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#
#                # base url and API requests
#                print(f"Retrieving Results for Index {index}: {locations}.")
#                hotel_name = requests.get(base_url, params=params)
#
#                # find lodging within 5000 meters of the city center
#                # extract results
#                hotel_name = hotel_name.json()
#
#                # use try-except to clear any exceptions
#                try:
#                    #print(f"Lodging available is {hotel_name["results"][0]["name"]}.")
#
#                    places.loc[index, "name"] = hotel_name["results"][0]["name"]
#                    places.loc[index, "address"] = hotel_name["results"][0]["vicinity"]
#                    #places.loc[index, "price_level"] = hotel_name["results"][0]["price_level"]
#                    places.loc[index, "rating"] = hotel_name["results"][0]["rating"]
#
#                except (KeyError, IndexError):
#                    print("Missing field/result... skipping.")
#
#                print("------------")
#
#
#            
# NEED MORE TIME TO GET THIS CODE BLOCK TO WORK.  LARGE INDENTS ARE FOR THE CODE THAT NEEDS TO BE ADJUSTED.

# %%
# check response url 
# !!!!!!!COMMENT OUT THIS PRINT STATEMENT SO OUTPUT WITH THE API KEY IS NOT EXPOSED WHEN COMMIT TO GITHUB!!!!
#print(response.url)

# %%
# Converting response to json
# places_data = response.json()

# %%
# Print the json to see results
#print(json.dumps(hotel_name, indent=4, sort_keys=True))
#pprint(hotel_name)
# THIS WORKS, BUT I ONLY GET THE RESULTS FOR THE LAST CITY LOCATION.  NEED TO ADJUST LOOP IN CODE BLOCK ABOVE.

# %%
test_city = ideal_winds["city"].tolist()
test_country = ideal_winds["country name"].tolist()
city_country = list(zip(test_city, test_country))
#print(city_country)

# %%
# Customize the size of the map
figure_layout = {
    'width': '80%',
    'margin': '0 auto 0 auto',
    'padding': '1px',
    'border': '1px solid black'
}

# Plot Heatmap
fig = gmaps.figure(layout=figure_layout, map_type='SATELLITE',
                  zoom_level=2, center=(30.267, -97.743),
                  display_toolbar=False)
# I TURNED OFF display_toolbar IN ORDER TO DOWNLOAD A PNG OF THE HEATMAP.  I TURNED IT BACK ON BEFORE I FILED.

# Create heatmap layer
heatmap_layer = gmaps.heatmap_layer(locations, weights=humid,
                                dissipating=False, max_intensity=79,
                                point_radius=5, opacity = 1.0)

# Assign the marker layer to markers
markers = gmaps.marker_layer(locations,
                            display_info_box=True,
                            info_box_content=test_city,
                            hover_text=test_city)
                             
#                            hover_text=['Nantucket', 'Terrace', 'Hibbing', 'Havre-St-Pierre', 'Libertador General San Martín', 'Vermillion',
#         'Tacuatí', 'Jadu', 'Korčula', 'Wajima'])

#hover_text="bluh\nbluh\nbluh")

# Add the layer to the map
fig.add_layer(markers)



# Add layer
fig.add_layer(heatmap_layer)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='420px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Well, if I would at least want to know if there is a hotel in each of these cities.

# %% [markdown]
# ### Markers are clickable, but they only have the city name right now.  Hover_text also works, but only with city name so far.
# -------
#
# ### I need to spend more time on the code block for the Google Places nearbyseach API results to get the markers to fully function with city, country, hotel.
